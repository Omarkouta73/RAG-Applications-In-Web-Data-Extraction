# %% [markdown]
# <a href="https://colab.research.google.com/github/Omarkouta73/RAG-Applications-In-Web-Data-Extraction/blob/main/Text/RAG_SemanticChunking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install faiss-cpu
# !pip install selenium
# !pip install google-generativeai
# !pip install -qU langchain-text-splitters
# !pip install langchain_experimental
#!pip install "unstructured[all-docs]"

# %%
import requests
from bs4 import BeautifulSoup
import faiss
import numpy as np
import torch
from transformers import pipeline
import google.generativeai as genai
from langchain_experimental.text_splitter import SemanticChunker
from langchain_text_splitters import HTMLSemanticPreservingSplitter
from unstructured.partition.html import partition_html
from langchain.embeddings import HuggingFaceEmbeddings
import nltk
from nltk.corpus import stopwords
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
import time
import random

device = "cuda" if torch.cuda.is_available() else "cpu"
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
# Step 1: Fetch HTML content
def get_cleaned_text(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')

    # Remove the specific div with id="customer-reviews_feature_div"
    customer_reviews_div = soup.find('div', id='customer-reviews_feature_div')
    if customer_reviews_div and hasattr(customer_reviews_div, 'decompose'):
        customer_reviews_div.decompose()

    # Remove unnecessary tags (scripts, styles, iframes, etc.)
    for tag in soup.find_all(['script', 'style', 'iframe', 'noscript', 'footer', 'header', 'a']):
        if tag and hasattr(tag, 'decompose'):
            tag.decompose()

    # Remove tags with ad-related keywords
    ad_keywords = ['ad', 'banner', 'promo', 'footer', 'sponsor', 'select', 'button']
    for tag in soup.find_all(ad_keywords):
        if tag and hasattr(tag, 'decompose'):
            tag.decompose()

    # Remove empty tags
    for tag in soup.find_all():
        if tag and not tag.get_text(strip=True):
            if hasattr(tag, 'decompose'):
                tag.decompose()

    return soup

def fetch_html(url):
    # List of user agents
    user_agents = [
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.121 Safari/537.36',
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/86.0.4240.75 Safari/537.36',
        'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/87.0.4280.66 Safari/537.36'
    ]

    # Chrome options
    chrome_options = Options()
    chrome_options.add_argument("--headless")  # Run headless
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument(f"user-agent={random.choice(user_agents)}")

    # Set location to Egypt
    chrome_options.add_argument("--lang=ar-EG")
    chrome_options.add_experimental_option("prefs", {
        "intl.accept_languages": "ar-EG,ar",
        "profile.default_content_setting_values.geolocation": 1
    })

    # Add geolocation for Cairo, Egypt
    chrome_options.add_argument("--enable-geolocation")
    chrome_options.add_argument("--use-fake-ui-for-media-stream")
    chrome_options.add_argument("--use-fake-device-for-media-stream")
    chrome_options.add_experimental_option("prefs", {
        "profile.default_content_settings.geolocation": 1,
        "profile.managed_default_content_settings.geolocation": 1,
        "profile.default_content_setting_values.geolocation": 1
    })

    service = Service()  # Windows
    driver = webdriver.Chrome(service=service, options=chrome_options)

    driver.execute_cdp_cmd("Emulation.setGeolocationOverride", {
        "latitude": 30.0444,
        "longitude": 31.2357,
        "accuracy": 100
    })

    time.sleep(random.uniform(5, 10))

    driver.get(url)

    return get_cleaned_text(driver.page_source)

def read_html(dir):
  with open(dir, "r", encoding="utf-8") as file:
        return file.read()

# %%
def langchain_SC(text, number_of_chunks=16, breakpoint_threshold_type="standard_deviation", model="all-MiniLM-L6-v2"):
  embedding_model = HuggingFaceEmbeddings(model_name=model)
  splitter = SemanticChunker(embedding_model, number_of_chunks=16, breakpoint_threshold_type="standard_deviation")
  chunks = splitter.create_documents([text])
  return chunks


def langchain_HSC(text):
  headers_to_split_on = [("h1", "Header 1"), ("h2", "Header 2")]
  splitter = HTMLSemanticPreservingSplitter(
      headers_to_split_on=headers_to_split_on,
      max_chunk_size=500,
      elements_to_preserve=["table", "ul", "li", "ol", "p"],
      chunk_overlap=0,
      denylist_tags=["script", "style", "head"],
      normalize_text=True,
      preserve_images=True,
      preserve_links=True,
      stopword_removal=False,
  )
  chunks = splitter.split_text(text)
  return chunks

nltk.download('stopwords')
# Define a set of English stopwords
stop_words = set(stopwords.words('english'))
def remove_stop_words(text):
  # Split the text into words, filter out stopwords, and join them back together.
  return ' '.join(word for word in text.split() if word not in stop_words)

def unstructured_ch(text, chunking_strategy="by_title"):
    # Partition the HTML/text into chunks
    chunks = partition_html(text=text, chunking_strategy=chunking_strategy)
    # For each chunk, lower-case the text and remove stop words
    return [remove_stop_words(chunk.text.lower()) for chunk in chunks]
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Step 3: Text Embedding
def embed_text(text, model):
    # Move model to GPU
    #model.to(device)

    # Get token embeddings
    token_embeddings = model(text, return_tensors="pt")[0].to(device)  # Move embeddings to GPU
    # Average the token embeddings to get a single vector
    chunk_embedding = token_embeddings.mean(dim=0).detach().cpu().numpy()  # Move back to CPU for FAISS
    return chunk_embedding

# %%
# Step 4: Query Embedding and Similarity Search
def search_similar_chunks(query, chunks, embeddings, model, top_k=3):
    query_embedding = embed_text(query, model)
    index = faiss.IndexFlatL2(embeddings.shape[1])
    index.add(embeddings)
    distances, indices = index.search(np.array([query_embedding]), top_k)
    return [chunks[i] for i in indices[0]]

# %%
# Step 5: LLM Processing with Gemini
def extract_info_with_llm(chunks, prompt):
    # Combine chunks into a single string
    combined_chunks = " ".join(chunks)

    # Initialize Gemini
    genai.configure(api_key="YOUR_GEMINI_API_KEY")  # Replace with your Gemini API key

    # Use the Gemini model
    model = genai.GenerativeModel('gemini-2.0-flash')  # Use the Gemini Pro model

    # Generate a response
    response = model.generate_content(f"""using these information: {combined_chunks} make your best to {prompt}
                                      , and provide it in ```json ``` format.
                                      give me 'NAN' if there is no direct answer in the provided information.""",
                                      generation_config={"max_output_tokens": 500})

    # Return the generated text
    return response.text

# %%
# Example Usage
url = "https://www.amazon.com/A315-24P-R7VH-Display-Quad-Core-Processor-Graphics/dp/B0BS4BP8FB/ref=sr_1_3?sr=8-3"
html = fetch_html(url)

# %%
#html = read_html("/content/page.html")

# %%
techniques = {
    "chunks_SC": langchain_SC(str(html)),
    "chunks_HSC": langchain_HSC(str(html)),
    "Unstructured": unstructured_ch(str(html))
}

# %%
# # Embed chunks
model1 = pipeline('feature-extraction', model='distilbert-base-uncased', padding=True, truncation=True, add_special_tokens = True)

# Option 1: Better pre-trained model
model2 = pipeline('feature-extraction',
                 model='sentence-transformers/all-MiniLM-L6-v2',
                 padding=True,
                 truncation=True,
                 add_special_tokens=True)

# Option 2: Another good alternative
# model3 = pipeline('feature-extraction',
#                  model='sentence-transformers/paraphrase-multilingual-MiniLM-L12-v2',
#                  padding=True,
#                  truncation=True,
#                  add_special_tokens=True)
# Out:
# Device set to use cpu
# Device set to use cpu

# %% [markdown]
# # Manual

# %%
#chunks = techniques['Text Splitter']; chunks #ch_con = [chunk.page_content for chunk in chunks];

# %%
#embeddings = np.array([embed_text(chunk, model) for chunk in chunks])

# %%
# Query
#query = "Extract product price"
#similar_chunks = search_similar_chunks(query, chunks, embeddings, top_k=3)

# %%
#similar_chunks

# %% [markdown]
# # Automatically

# %%
def prompt(query, model, k=3):
  prompt = query
  start_time = time.time()
  no_chunk_result = extract_info_with_llm(str(html), prompt)
  no_chunk_time = (time.time() - start_time) * 1000  # Convert to milliseconds
  print(f"No-Chunking: {no_chunk_result}")
  print(f"Time: {no_chunk_time:.2f} ms")
  print("==============================================================================")
  # Measure each chunking technique
  for key, chunks in techniques.items():
      start_time = time.time()

      if type(chunks[0]) != str:
          chunks = [chunk.page_content for chunk in chunks]
      print(key,":")
      print("Chunks: ", chunks)

      embeddings = np.array([embed_text(chunk, model) for chunk in chunks])
      print("Embeddings Shape: ", embeddings.shape)

      similar_chunks = search_similar_chunks(query, chunks, embeddings, model, top_k=k)
      print("Similar Chunks: ", similar_chunks)

      result = extract_info_with_llm(similar_chunks, prompt)
      execution_time = (time.time() - start_time) * 1000  # Convert to milliseconds

      print("Response:", result)
      print(f"Time: {execution_time:.2f} ms")
      print("==============================================================================")

# %% [markdown]
# ## distilbert-base-uncased

# %%
prompt("Extract the amount of RAM memory installed", model1, k=3)
# Out:
# No-Chunking: ```json
# {
#   "ram_memory_installed": "8 GB"
# }
# ```
# Time: 4659.91 ms
# ==============================================================================
# chunks_SC :
# Chunks:  ['<html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.25.1-2025-03-08" lang="en-us"><!-- sp:feature:head-start --><!-- sp:end-feature:head-close -->\n<!-- sp:feature:start-body -->\n<body class="a-m-us a-aui_72554-c a-aui_a11y_6_837773-c a-aui_killswitch_csa_logger_372963-t1 a-aui_pci_risk_banner_210084-c a-aui_template_weblab_cache_333406-c a-aui_tnr_v2_180836-c a-bw_aui_cxc_alert_measurement_1074111-c a-meter-animate"><div id="a-page"><!-- sp:end-feature:start-body -->\n<!-- sp:feature:csm:body-open -->\n\n\n<!-- sp:end-feature:csm:body-open -->\n<!-- sp:feature:nav-inline-js -->\n<!-- NAVYAAN JS -->\n\n\n\n\n\n<!-- sp:end-feature:nav-inline-js -->\n<!-- sp:feature:nav-skeleton -->\n<!-- sp:end-feature:nav-skeleton -->\n<!-- sp:feature:navbar -->\n<!--Pilu -->\n<!-- NAVYAAN-BACKUP -->\n<!-- navmet initial definition -->\n\n\n\n\n\n\n\n\n<nav aria-label="Shortcuts menu" class="nav-assistant" id="shortcut-menu" role="navigation" tabindex="-1">\n<h2 class="nav-assistant-heading nav-assistant-headers-font" id="nav-assistant-links-heading">Skip to</h2>\n\n\n<h2 class="nav-assistant-heading nav-assistant-headers-font font-color" id="shortcuts-heading">\n      Keyboard shortcuts\n  </h2>\n\n<div id="nav-assist-shortcut-help">\n<div class="shortcut-help-container">\n<div class="shortcut-help-item-container">\n\n<div class="help-text-container">\n<span class="shortcut-help-text font-color">To move between items, use your keyboard\'s up or down arrows.</span>\n</div>\n</div>\n</div>\n</div>\n</nav>\n\n\n\n\n\n\n\n\n<!-- sp:end-feature:navbar -->\n<!-- sp:feature:configured-sitewide-before-host-atf-assets -->\n\n<!-- sp:end-feature:configured-sitewide-before-host-atf-assets -->\n<!-- sp:feature:host-atf -->\n<title>Amazon.com: Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Full HD IPS Display | AMD Ryzen 3 7320U Quad-Core Processor | AMD Radeon Graphics | 8GB LPDDR5 | 128GB NVMe SSD | Wi-Fi 6 | Windows 11 Home in S Mode : Electronics</title>\n\n<div class="pc en_US" id="dp">\n\n<div class="a-container" id="dp-container" role="main">\n\n\n\n\n<div class="a-section" id="above-dp-container"> \n\n\n\n\n\n<div class="celwidget" data-cel-widget="desktop-breadcrumbs_feature_div" data-csa-c-asin="" data-csa-c-content-id="desktop-breadcrumbs" data-csa-c-id="nqlj00-f5qepk-6s20o-udmatk" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="desktop-breadcrumbs_feature_div" data-csa-c-type="widget" data-feature-name="desktop-breadcrumbs" id="desktop-breadcrumbs_feature_div">\n<div cel_widget_id="seo-breadcrumb-desktop-card_DetailPage_5" class="celwidget c-f" data-cel-widget="seo-breadcrumb-desktop-card_DetailPage_5" data-csa-c-content-id="DsUnknown" data-csa-c-id="yz0tuv-4rg0lg-rod6hk-f5lytl" data-csa-c-painter="seo-breadcrumb-desktop-card-cards" data-csa-c-slot-id="DsUnknown-6" data-csa-c-type="widget" data-csa-op-log-render=""><!--CardsClient--><div class="a-section a-spacing-none a-padding-medium" data-card-metrics-id="seo-breadcrumb-desktop-card_DetailPage_5" id="CardInstance5Jgd1gGrRUHVHs-h062CKA"><div class="a-subheader a-breadcrumb feature" data-cel-widget="wayfinding-breadcrumbs_feature_div" data-feature-name="wayfinding-breadcrumbs" id="wayfinding-breadcrumbs_feature_div"><ul class="a-unordered-list a-horizontal a-size-small"><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li></ul></div></div></div> </div>\n ...
# Embeddings Shape:  (16, 768)
# Similar Chunks:  ['This Aspire 3 can tackle any job no matter how complex. Creativity soars to new heights with sharp, crisp visuals showcased on the 15.6" Full HD IPS screen, while the thin bezel provides you with more space to work with wherever inspiration strikes. It’s the perfect companion to take with you wherever you go With Windows 11 Home in S mode, you’ll experience fast start-ups, a familiar yet expanded Start menu, and great new ways to get stuff done.', '</p> </div> </div><div class="a-section a-spacing-none premium-aplus-column">  <div class="a-section a-spacing-none column-heading"> <h1 class="aplus-h3 a-text-bold"> Get a Fresh Perspective </h1> </div> <div class="a-section a-spacing-none column-description"> <p class="aplus-p3"> Family, friends, obsessions, music, creations—Windows 11 Home in S mode is the one place for it all. With a fresh new feel and tools that make it easier to be efficient, it has what you need for whatever’s next.', '</span></li> <li class="a-spacing-mini"><span class="a-list-item"> Visibly Stunning: Experience sharp details and crisp colors on the 15.6" Full HD IPS display with 16:9 aspect ratio and narrow bezels. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Internal Specifications: 8GB LPDDR5 Onboard Memory; 128GB NVMe solid-state drive storage to store your files and media  </span></li> <li class="a-spacing-mini"><span class="a-list-item"> The HD front-facing camera uses Acer’s TNR (Temporal Noise Reduction) technology for high-quality imagery in low-light conditions. Acer PurifiedVoice technology with AI Noise Reduction filters out any extra sound for clear communication over online meetings. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Wireless Wi-Fi 6 Convenience: Maintain a strong, consistent wireless signal with Wi-Fi 6 (aka 802.11ax) and 2x2 MU-MIMO technology. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Improved Thermals: With a 78% increase in fan surface area, enjoy an improved thermal system and an additional 17% thermal capacity. Allowing for longer, more efficient work sessions while not plugged in. </span></li> </ul> <!-- Loading EDP related metadata -->\n<div class="a-row a-expander-container a-expander-inline-container"> <div class="a-expander-content a-expander-extend-content" data-expanded="false" style="display:none"> <ul class="a-unordered-list a-vertical a-spacing-none"> <li class="a-spacing-mini"><span class="a-list-item">Ports For All Your Accessories: 1 - USB Type-C Port USB 3.2 Gen 2 (up to 10 Gbps) DisplayPort over USB Type-C &amp; USB Charging, 2 - USB 3.2 Gen 1 Ports, 1 - HDMI 2.1 Port with HDCP support, 1 - Headphone/Speaker/Line-Out Jack, DC-in for AC adapter</span></li> <li class="a-spacing-mini"><span class="a-list-item">What\'s In the Box: Acer Aspire Laptop, AC Adapter, Power Cord</span></li> <li class="a-spacing-mini"><span class="a-list-item">Keyboard backlight not present on this model</span></li> </ul> </div>  </div> <div class="a-section aok-hidden" data-csa-c-content-id="voyager-product-details-jumplink" data-csa-c-id="twcewi-hu2ttu-4fs2bc-z2oear" data-csa-c-slot-id="voyager-product-details-jumplink" data-csa-c-type="link"> <span class="caretnext">›</span>  </div> </div> </div>\n</div>  </div>\n<div class="celwidget" data-cel-widget="depthInfoCard_1" data-csa-c-asin="B0BS4BP8FB" data-csa-c-content-id="depthInfoCard_1" data-csa-c-id="4dq6pw-hq7g0a-vgwwhu-7jyk44" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="depthInfoCard_1" data-csa-c-type="widget" data-feature-name="depthInfoCard_1" id="depthInfoCard_1">\n  <div class="a-section aok-hidden hoc-pill-content" id="hoc-depthInfoCard_1"> <div class="celwidget" data-cel-widget="depthInfoGrouping_1_feature_div" data-csa-c-asin="B0BS4BP8FB" data-csa-c-content-id="depthInfoGrouping_1" data-csa-c-id="ozcin4-o1qmni-yn9v4y-vyov2k" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="depthInfoGrouping_1_feature_div" ...
# Response: ```json
# {
#   "RAM Memory Installed": "8 GB"
# }
# ```
# Time: 16693.05 ms
# ==============================================================================
# chunks_HSC :
# Chunks:  ['skip keyboard shortcuts move items use keyboards arrows amazoncom acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home mode electronics  buy new see product details add item cart return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option drop', 'leave ships amazoncom sold amazoncom spcsrf spendcsrf see product details add item cart always remove later return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option drop leave quantity quantity 1 add cart buy enhancements chose arent available seller add following enhancements purchase choose different seller cardname cardname available seller chose cardname', 'unavailable quantities greater maxquantity ships amazoncom ships amazoncom sold amazoncom sold amazoncom returns 30day refundreplacement item returned original condition full refund replacement within 30 days receipt clean buyx_offersx_dod_gifting_jsp_param_optimization_1084861 sim httpsissuesamazoncomissuesofxs2531 sim httpsissuesamazoncomissuesofxs2617 fix typo popvername occurrence fixed buyx_offersx_dod_gifting_jsp_param_optimization_1084861 cleaned favor t1 gift options gets template', 'gifting teams package files added use cases content type checkout add custom message gift receipt easy returns item giftwrapped add gift options checkout payment transaction secure work hard protect security privacy payment security system encrypts information transmission dont share credit card details thirdparty sellers dont sell information others support whats product support event product doesnt work expected need help using amazon offers free product support options live phonechat amazon', 'associate manufacturer contact information stepbystep troubleshooting guides help videos solving product issues help planet extending life products availability support options differ product country save used like new see product details add item cart ships macluvin sold macluvin spcsrf spendcsrf see product details add item cart always remove later add cart enhancements chose arent available seller add following enhancements purchase choose different seller cardname cardname available seller', 'chose cardname unavailable quantities greater maxquantity ships sold spcsrf spendcsrf add list added unable add item list please try sorry problem error retrieving wish lists please try sorry problem list unavailable spcsrf spendcsrf sellers amazon 9 8 7 6 5 4 10 videos video showcases product use video guides product setup video compares multiple products video shows product unpacked video player loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions selected', 'captions selected default selected modal window microsoft windows copilot acer america corporation image unavailable image available forcolor view video download roll image zoom video showcases product use video guides product setup video compares multiple products video shows product unpacked video player loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions selected 9 8 7 6 5 4 10 videos0 9 8 7 6 5 4 10 videos1 9 8 7 6 5 4 10 videos2 customer review microsoft windows copilot verified purchase earns', 'commissions verified purchase earns commissions ask rufus', 'amazons choice highlights highly rated wellpriced products available ship immediately amazons choice 4k bought past month see product details add item cart always remove later return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option dro ...
# Embeddings Shape:  (28, 768)
# Similar Chunks:  ['choose items buy together', 'would like acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home mode share found lower price let us know although cant match every price reported well use feedback ensure prices remain competitive', 'maintain strong consistent wireless signal wifi 6 aka 80211ax 2x2 mumimo technology strategic slot antenna placement helps maximize portability wireless performance laptop']
# Response: ```json
# {
#   "RAM": "8GB"
# }
# ```
# Time: 7527.46 ms
# ==============================================================================
# Unstructured :
# Chunks:  ['› › › › buy new: see product details, add item cart.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! ships from: amazon.com sold by: amazon.com save used - like new see product details, add item cart. ships from: macluvin sold by: macluvin sellers amazon 9+ 8+ 7+ 6+ 5+ 4+ 10 videos', 'video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window. microsoft windows copilotacer america corporation', 'image unavailable image available forcolor: view video download roll image zoom video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window.', 'customer review: microsoft windows copilot acer america corporation verified purchase earns commissions verified purchase earns commissions ask rufus', 'acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode amazon\'s choice highlights highly rated, well-priced products available ship immediately. amazon\'s choice 4k+ bought past month see product details, add item cart. always remove later.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! see product details, add item cart. always remove later. available lower price may offer free prime shipping. brief content visible, double tap read full content.', 'full content visible, double tap read brief content. cpu: r3 7320u r3 7320u $299.99 7 percent savings$299.99 $321.99$321.99 stock r5 7520u see available options r7 5825u see available options a314-23p-r3qa see available options style: 15.6 inch / 8gb / 128gb 15.6 inch / 8gb / 128gb 14-inch / 8gb / 512gb 15.6 inch / 16gb / 512gb 15.6 inch touch / 16gb / 512gb', 'purchase options add-ons brief content visible, double tap read full content. full content visible, double tap read brief content. product details top highlights item details display processor memory ports & slots brand acer model name laptop screen size 15.6 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'item purposeful design: travel ease look great aspire\'s 3 thin, light design. ready-to-go performance: aspire 3 ready-to-go latest amd ryzen 3 7320u processor radeon graphics—ideal entire family, performance productivity core. visibly stunning: experience sharp details crisp colors 15.6" full hd ips display 16:9 aspect ratio narrow bezels.', 'internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.', 'wireless wi-fi 6 convenience: maintain strong, consistent wireless signal wi-fi 6 (aka 802.11ax) 2x2 mu-mimo technology. improved thermals: 78% increase fan surface area, enjoy improved thermal system additional 17% thermal capacity. allowing longer, efficient work sessions plugged in.', "ports accessories: 1 - usb type-c port usb ...
# Embeddings Shape:  (41, 768)
# Similar Chunks:  ['video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window. microsoft windows copilotacer america corporation', 'wherever go windows 11 home mode, you’ll experience fast start-ups, familiar yet expanded start menu, great new ways get stuff done. automatic updates enabled, get latest features security hassle-free. work, play share one device (nx.kjbaa.001).', 'internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.']
# Response: ```json
# {
#   "RAM": "8GB"
# }
# ```
# Time: 7191.92 ms
# ==============================================================================

# %%
prompt("Extract the laptop price", model1, k=3)
# Out:
# No-Chunking: ```json
# {
#   "laptop_price": "$299.99"
# }
# ```
# Time: 6057.44 ms
# ==============================================================================
# chunks_SC :
# Chunks:  ['<html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.25.1-2025-03-08" lang="en-us"><!-- sp:feature:head-start --><!-- sp:end-feature:head-close -->\n<!-- sp:feature:start-body -->\n<body class="a-m-us a-aui_72554-c a-aui_a11y_6_837773-c a-aui_killswitch_csa_logger_372963-t1 a-aui_pci_risk_banner_210084-c a-aui_template_weblab_cache_333406-c a-aui_tnr_v2_180836-c a-bw_aui_cxc_alert_measurement_1074111-c a-meter-animate"><div id="a-page"><!-- sp:end-feature:start-body -->\n<!-- sp:feature:csm:body-open -->\n\n\n<!-- sp:end-feature:csm:body-open -->\n<!-- sp:feature:nav-inline-js -->\n<!-- NAVYAAN JS -->\n\n\n\n\n\n<!-- sp:end-feature:nav-inline-js -->\n<!-- sp:feature:nav-skeleton -->\n<!-- sp:end-feature:nav-skeleton -->\n<!-- sp:feature:navbar -->\n<!--Pilu -->\n<!-- NAVYAAN-BACKUP -->\n<!-- navmet initial definition -->\n\n\n\n\n\n\n\n\n<nav aria-label="Shortcuts menu" class="nav-assistant" id="shortcut-menu" role="navigation" tabindex="-1">\n<h2 class="nav-assistant-heading nav-assistant-headers-font" id="nav-assistant-links-heading">Skip to</h2>\n\n\n<h2 class="nav-assistant-heading nav-assistant-headers-font font-color" id="shortcuts-heading">\n      Keyboard shortcuts\n  </h2>\n\n<div id="nav-assist-shortcut-help">\n<div class="shortcut-help-container">\n<div class="shortcut-help-item-container">\n\n<div class="help-text-container">\n<span class="shortcut-help-text font-color">To move between items, use your keyboard\'s up or down arrows.</span>\n</div>\n</div>\n</div>\n</div>\n</nav>\n\n\n\n\n\n\n\n\n<!-- sp:end-feature:navbar -->\n<!-- sp:feature:configured-sitewide-before-host-atf-assets -->\n\n<!-- sp:end-feature:configured-sitewide-before-host-atf-assets -->\n<!-- sp:feature:host-atf -->\n<title>Amazon.com: Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Full HD IPS Display | AMD Ryzen 3 7320U Quad-Core Processor | AMD Radeon Graphics | 8GB LPDDR5 | 128GB NVMe SSD | Wi-Fi 6 | Windows 11 Home in S Mode : Electronics</title>\n\n<div class="pc en_US" id="dp">\n\n<div class="a-container" id="dp-container" role="main">\n\n\n\n\n<div class="a-section" id="above-dp-container"> \n\n\n\n\n\n<div class="celwidget" data-cel-widget="desktop-breadcrumbs_feature_div" data-csa-c-asin="" data-csa-c-content-id="desktop-breadcrumbs" data-csa-c-id="nqlj00-f5qepk-6s20o-udmatk" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="desktop-breadcrumbs_feature_div" data-csa-c-type="widget" data-feature-name="desktop-breadcrumbs" id="desktop-breadcrumbs_feature_div">\n<div cel_widget_id="seo-breadcrumb-desktop-card_DetailPage_5" class="celwidget c-f" data-cel-widget="seo-breadcrumb-desktop-card_DetailPage_5" data-csa-c-content-id="DsUnknown" data-csa-c-id="yz0tuv-4rg0lg-rod6hk-f5lytl" data-csa-c-painter="seo-breadcrumb-desktop-card-cards" data-csa-c-slot-id="DsUnknown-6" data-csa-c-type="widget" data-csa-op-log-render=""><!--CardsClient--><div class="a-section a-spacing-none a-padding-medium" data-card-metrics-id="seo-breadcrumb-desktop-card_DetailPage_5" id="CardInstance5Jgd1gGrRUHVHs-h062CKA"><div class="a-subheader a-breadcrumb feature" data-cel-widget="wayfinding-breadcrumbs_feature_div" data-feature-name="wayfinding-breadcrumbs" id="wayfinding-breadcrumbs_feature_div"><ul class="a-unordered-list a-horizontal a-size-small"><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li></ul></div></div></div> </div>\n ...
# Embeddings Shape:  (16, 768)
# Similar Chunks:  ['This Aspire 3 can tackle any job no matter how complex. Creativity soars to new heights with sharp, crisp visuals showcased on the 15.6" Full HD IPS screen, while the thin bezel provides you with more space to work with wherever inspiration strikes. It’s the perfect companion to take with you wherever you go With Windows 11 Home in S mode, you’ll experience fast start-ups, a familiar yet expanded Start menu, and great new ways to get stuff done.', '</p> </div> </div><div class="a-section a-spacing-none premium-aplus-column">  <div class="a-section a-spacing-none column-heading"> <h1 class="aplus-h3 a-text-bold"> Get a Fresh Perspective </h1> </div> <div class="a-section a-spacing-none column-description"> <p class="aplus-p3"> Family, friends, obsessions, music, creations—Windows 11 Home in S mode is the one place for it all. With a fresh new feel and tools that make it easier to be efficient, it has what you need for whatever’s next.', '</span></li> <li class="a-spacing-mini"><span class="a-list-item"> Visibly Stunning: Experience sharp details and crisp colors on the 15.6" Full HD IPS display with 16:9 aspect ratio and narrow bezels. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Internal Specifications: 8GB LPDDR5 Onboard Memory; 128GB NVMe solid-state drive storage to store your files and media  </span></li> <li class="a-spacing-mini"><span class="a-list-item"> The HD front-facing camera uses Acer’s TNR (Temporal Noise Reduction) technology for high-quality imagery in low-light conditions. Acer PurifiedVoice technology with AI Noise Reduction filters out any extra sound for clear communication over online meetings. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Wireless Wi-Fi 6 Convenience: Maintain a strong, consistent wireless signal with Wi-Fi 6 (aka 802.11ax) and 2x2 MU-MIMO technology. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Improved Thermals: With a 78% increase in fan surface area, enjoy an improved thermal system and an additional 17% thermal capacity. Allowing for longer, more efficient work sessions while not plugged in. </span></li> </ul> <!-- Loading EDP related metadata -->\n<div class="a-row a-expander-container a-expander-inline-container"> <div class="a-expander-content a-expander-extend-content" data-expanded="false" style="display:none"> <ul class="a-unordered-list a-vertical a-spacing-none"> <li class="a-spacing-mini"><span class="a-list-item">Ports For All Your Accessories: 1 - USB Type-C Port USB 3.2 Gen 2 (up to 10 Gbps) DisplayPort over USB Type-C &amp; USB Charging, 2 - USB 3.2 Gen 1 Ports, 1 - HDMI 2.1 Port with HDCP support, 1 - Headphone/Speaker/Line-Out Jack, DC-in for AC adapter</span></li> <li class="a-spacing-mini"><span class="a-list-item">What\'s In the Box: Acer Aspire Laptop, AC Adapter, Power Cord</span></li> <li class="a-spacing-mini"><span class="a-list-item">Keyboard backlight not present on this model</span></li> </ul> </div>  </div> <div class="a-section aok-hidden" data-csa-c-content-id="voyager-product-details-jumplink" data-csa-c-id="twcewi-hu2ttu-4fs2bc-z2oear" data-csa-c-slot-id="voyager-product-details-jumplink" data-csa-c-type="link"> <span class="caretnext">›</span>  </div> </div> </div>\n</div>  </div>\n<div class="celwidget" data-cel-widget="depthInfoCard_1" data-csa-c-asin="B0BS4BP8FB" data-csa-c-content-id="depthInfoCard_1" data-csa-c-id="4dq6pw-hq7g0a-vgwwhu-7jyk44" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="depthInfoCard_1" data-csa-c-type="widget" data-feature-name="depthInfoCard_1" id="depthInfoCard_1">\n  <div class="a-section aok-hidden hoc-pill-content" id="hoc-depthInfoCard_1"> <div class="celwidget" data-cel-widget="depthInfoGrouping_1_feature_div" data-csa-c-asin="B0BS4BP8FB" data-csa-c-content-id="depthInfoGrouping_1" data-csa-c-id="ozcin4-o1qmni-yn9v4y-vyov2k" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="depthInfoGrouping_1_feature_div" ...
# Response: ```json
# {
#   "laptop_price": "$299.99"
# }
# ```
# Time: 16966.26 ms
# ==============================================================================
# chunks_HSC :
# Chunks:  ['skip to keyboard shortcuts to move between items use your keyboards up or down arrows amazoncom acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home in s mode electronics  buy new to see product details add this item to your cart return this item for free we offer easy convenient returns with at least one free return option no shipping charges all returns must comply with', 'our returns policy go to your orders and start the return select your preferred free shipping option drop off and leave ships from amazoncom sold by amazoncom spcsrf spendcsrf to see product details add this item to your cart you can always remove it later return this item for free we offer easy convenient returns with at least one free return option no shipping charges all returns must comply with our returns policy go to your orders and start the return select your preferred free shipping', 'option drop off and leave quantity quantity 1 add to cart buy now enhancements you chose arent available for this seller to add the following enhancements to your purchase choose a different seller cardname cardname not available for the seller you chose cardname unavailable for quantities greater than maxquantity ships from amazoncom ships from amazoncom sold by amazoncom sold by amazoncom returns 30day refundreplacement this item can be returned in its original condition for a full refund or', 'replacement within 30 days of receipt clean up buyx_offersx_dod_gifting_jsp_param_optimization_1084861 sim httpsissuesamazoncomissuesofxs2531 sim httpsissuesamazoncomissuesofxs2617 to fix typo in popvername this occurrence should be fixed if buyx_offersx_dod_gifting_jsp_param_optimization_1084861 is cleaned up in favor of t1 gift options gets the template from gifting teams package other files will be added here for other use cases with same content type at checkout you can add a custom message', 'a gift receipt for easy returns and have the item giftwrapped add gift options at checkout payment your transaction is secure we work hard to protect your security and privacy our payment security system encrypts your information during transmission we dont share your credit card details with thirdparty sellers and we dont sell your information to others support whats product support in the event your product doesnt work as expected or you need help using it amazon offers free product support', 'options such as live phonechat with an amazon associate manufacturer contact information stepbystep troubleshooting guides and help videos by solving product issues we help the planet by extending the life of products availability of support options differ by product and country save with used like new to see product details add this item to your cart ships from macluvin sold by macluvin spcsrf spendcsrf to see product details add this item to your cart you can always remove it later add to', 'cart enhancements you chose arent available for this seller to add the following enhancements to your purchase choose a different seller cardname cardname not available for the seller you chose cardname unavailable for quantities greater than maxquantity ships from and sold by spcsrf spendcsrf add to list added to unable to add item to list please try again sorry there was a problem there was an error retrieving your wish lists please try again sorry there was a problem list unavailable spcsrf', 'spendcsrf other sellers on amazon 9 8 7 6 5 4 10 videos the video showcases the product in use the video guides you through product setup the video compares multiple products the video shows the product being unpacked video player is loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions off selected captions off selected default selected this is a modal window microsoft windows copilot acer america corporation image unavailable image not  ...
# Embeddings Shape:  (29, 768)
# Similar Chunks:  ['price 32391 323 91 spcsrf_treatment add all 3 to cart these items are shipped from and sold by different sellers choose items to buy together', '19962025 amazoncom inc or its affiliates', 'maintain a strong consistent wireless signal with wifi 6 aka 80211ax and 2x2 mumimo technology the strategic slot antenna placement helps maximize the portability and wireless performance of your laptop']
# Response: ```json
# {
#   "laptop_price": "NAN"
# }
# ```
#
# Time: 7467.39 ms
# ==============================================================================
# Unstructured :
# Chunks:  ['› › › › buy new: see product details, add item cart.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! ships from: amazon.com sold by: amazon.com save used - like new see product details, add item cart. ships from: macluvin sold by: macluvin sellers amazon 9+ 8+ 7+ 6+ 5+ 4+ 10 videos', 'video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window. microsoft windows copilotacer america corporation', 'image unavailable image available forcolor: view video download roll image zoom video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window.', 'customer review: microsoft windows copilot acer america corporation verified purchase earns commissions verified purchase earns commissions ask rufus', 'acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode amazon\'s choice highlights highly rated, well-priced products available ship immediately. amazon\'s choice 4k+ bought past month see product details, add item cart. always remove later.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! see product details, add item cart. always remove later. available lower price may offer free prime shipping. brief content visible, double tap read full content.', 'full content visible, double tap read brief content. cpu: r3 7320u r3 7320u $299.99 7 percent savings$299.99 $321.99$321.99 stock r5 7520u see available options r7 5825u see available options a314-23p-r3qa see available options style: 15.6 inch / 8gb / 128gb 15.6 inch / 8gb / 128gb 14-inch / 8gb / 512gb 15.6 inch / 16gb / 512gb 15.6 inch touch / 16gb / 512gb', 'purchase options add-ons brief content visible, double tap read full content. full content visible, double tap read brief content. product details top highlights item details display processor memory ports & slots brand acer model name laptop screen size 15.6 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'item purposeful design: travel ease look great aspire\'s 3 thin, light design. ready-to-go performance: aspire 3 ready-to-go latest amd ryzen 3 7320u processor radeon graphics—ideal entire family, performance productivity core. visibly stunning: experience sharp details crisp colors 15.6" full hd ips display 16:9 aspect ratio narrow bezels.', 'internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.', 'wireless wi-fi 6 convenience: maintain strong, consistent wireless signal wi-fi 6 (aka 802.11ax) 2x2 mu-mimo technology. improved thermals: 78% increase fan surface area, enjoy improved thermal system additional 17% thermal capacity. allowing longer, efficient work sessions plugged in.', "ports accessories: 1 - usb type-c port usb ...
# Embeddings Shape:  (41, 768)
# Similar Chunks:  ['see lower price? fields asterisk * required submit feedback please provide feedback. compare similar items', 'unsellable condition due customer tampering result customer charged higher restocking fee based condition product. amazon.com accept returns desktop notebook computer 30 days receive shipment. new, used, refurbished products purchased marketplace vendors subject returns policy individual vendor.', 'stock sold booeudi.llc ships amazon fulfillment. total price: $323.91$323.91 see price, add items cart. try again! added cart items shipped sold different sellers. choose items buy together.']
# Response: ```json
# {
#   "laptop_price": "$323.91"
# }
# ```
# Time: 8283.61 ms
# ==============================================================================

# %%
prompt("Does the laptop has front-facing camera ?", model1, k=3)
# Out:
# No-Chunking: ```json
# {
#   "front_facing_camera": "yes"
# }
# ```
# Time: 4954.57 ms
# ==============================================================================
# chunks_SC :
# Chunks:  ['<html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.25.1-2025-03-08" lang="en-us"><!-- sp:feature:head-start --><!-- sp:end-feature:head-close -->\n<!-- sp:feature:start-body -->\n<body class="a-m-us a-aui_72554-c a-aui_a11y_6_837773-c a-aui_killswitch_csa_logger_372963-t1 a-aui_pci_risk_banner_210084-c a-aui_template_weblab_cache_333406-c a-aui_tnr_v2_180836-c a-bw_aui_cxc_alert_measurement_1074111-c a-meter-animate"><div id="a-page"><!-- sp:end-feature:start-body -->\n<!-- sp:feature:csm:body-open -->\n\n\n<!-- sp:end-feature:csm:body-open -->\n<!-- sp:feature:nav-inline-js -->\n<!-- NAVYAAN JS -->\n\n\n\n\n\n<!-- sp:end-feature:nav-inline-js -->\n<!-- sp:feature:nav-skeleton -->\n<!-- sp:end-feature:nav-skeleton -->\n<!-- sp:feature:navbar -->\n<!--Pilu -->\n<!-- NAVYAAN-BACKUP -->\n<!-- navmet initial definition -->\n\n\n\n\n\n\n\n\n<nav aria-label="Shortcuts menu" class="nav-assistant" id="shortcut-menu" role="navigation" tabindex="-1">\n<h2 class="nav-assistant-heading nav-assistant-headers-font" id="nav-assistant-links-heading">Skip to</h2>\n\n\n<h2 class="nav-assistant-heading nav-assistant-headers-font font-color" id="shortcuts-heading">\n      Keyboard shortcuts\n  </h2>\n\n<div id="nav-assist-shortcut-help">\n<div class="shortcut-help-container">\n<div class="shortcut-help-item-container">\n\n<div class="help-text-container">\n<span class="shortcut-help-text font-color">To move between items, use your keyboard\'s up or down arrows.</span>\n</div>\n</div>\n</div>\n</div>\n</nav>\n\n\n\n\n\n\n\n\n<!-- sp:end-feature:navbar -->\n<!-- sp:feature:configured-sitewide-before-host-atf-assets -->\n\n<!-- sp:end-feature:configured-sitewide-before-host-atf-assets -->\n<!-- sp:feature:host-atf -->\n<title>Amazon.com: Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Full HD IPS Display | AMD Ryzen 3 7320U Quad-Core Processor | AMD Radeon Graphics | 8GB LPDDR5 | 128GB NVMe SSD | Wi-Fi 6 | Windows 11 Home in S Mode : Electronics</title>\n\n<div class="pc en_US" id="dp">\n\n<div class="a-container" id="dp-container" role="main">\n\n\n\n\n<div class="a-section" id="above-dp-container"> \n\n\n\n\n\n<div class="celwidget" data-cel-widget="desktop-breadcrumbs_feature_div" data-csa-c-asin="" data-csa-c-content-id="desktop-breadcrumbs" data-csa-c-id="nqlj00-f5qepk-6s20o-udmatk" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="desktop-breadcrumbs_feature_div" data-csa-c-type="widget" data-feature-name="desktop-breadcrumbs" id="desktop-breadcrumbs_feature_div">\n<div cel_widget_id="seo-breadcrumb-desktop-card_DetailPage_5" class="celwidget c-f" data-cel-widget="seo-breadcrumb-desktop-card_DetailPage_5" data-csa-c-content-id="DsUnknown" data-csa-c-id="yz0tuv-4rg0lg-rod6hk-f5lytl" data-csa-c-painter="seo-breadcrumb-desktop-card-cards" data-csa-c-slot-id="DsUnknown-6" data-csa-c-type="widget" data-csa-op-log-render=""><!--CardsClient--><div class="a-section a-spacing-none a-padding-medium" data-card-metrics-id="seo-breadcrumb-desktop-card_DetailPage_5" id="CardInstance5Jgd1gGrRUHVHs-h062CKA"><div class="a-subheader a-breadcrumb feature" data-cel-widget="wayfinding-breadcrumbs_feature_div" data-feature-name="wayfinding-breadcrumbs" id="wayfinding-breadcrumbs_feature_div"><ul class="a-unordered-list a-horizontal a-size-small"><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li></ul></div></div></div> </div>\n ...
# Embeddings Shape:  (16, 768)
# Similar Chunks:  ['This Aspire 3 can tackle any job no matter how complex. Creativity soars to new heights with sharp, crisp visuals showcased on the 15.6" Full HD IPS screen, while the thin bezel provides you with more space to work with wherever inspiration strikes. It’s the perfect companion to take with you wherever you go With Windows 11 Home in S mode, you’ll experience fast start-ups, a familiar yet expanded Start menu, and great new ways to get stuff done.', '</p> </div> </div><div class="a-section a-spacing-none premium-aplus-column">  <div class="a-section a-spacing-none column-heading"> <h1 class="aplus-h3 a-text-bold"> Get a Fresh Perspective </h1> </div> <div class="a-section a-spacing-none column-description"> <p class="aplus-p3"> Family, friends, obsessions, music, creations—Windows 11 Home in S mode is the one place for it all. With a fresh new feel and tools that make it easier to be efficient, it has what you need for whatever’s next.', '</span></li> <li class="a-spacing-mini"><span class="a-list-item"> Visibly Stunning: Experience sharp details and crisp colors on the 15.6" Full HD IPS display with 16:9 aspect ratio and narrow bezels. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Internal Specifications: 8GB LPDDR5 Onboard Memory; 128GB NVMe solid-state drive storage to store your files and media  </span></li> <li class="a-spacing-mini"><span class="a-list-item"> The HD front-facing camera uses Acer’s TNR (Temporal Noise Reduction) technology for high-quality imagery in low-light conditions. Acer PurifiedVoice technology with AI Noise Reduction filters out any extra sound for clear communication over online meetings. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Wireless Wi-Fi 6 Convenience: Maintain a strong, consistent wireless signal with Wi-Fi 6 (aka 802.11ax) and 2x2 MU-MIMO technology. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Improved Thermals: With a 78% increase in fan surface area, enjoy an improved thermal system and an additional 17% thermal capacity. Allowing for longer, more efficient work sessions while not plugged in. </span></li> </ul> <!-- Loading EDP related metadata -->\n<div class="a-row a-expander-container a-expander-inline-container"> <div class="a-expander-content a-expander-extend-content" data-expanded="false" style="display:none"> <ul class="a-unordered-list a-vertical a-spacing-none"> <li class="a-spacing-mini"><span class="a-list-item">Ports For All Your Accessories: 1 - USB Type-C Port USB 3.2 Gen 2 (up to 10 Gbps) DisplayPort over USB Type-C &amp; USB Charging, 2 - USB 3.2 Gen 1 Ports, 1 - HDMI 2.1 Port with HDCP support, 1 - Headphone/Speaker/Line-Out Jack, DC-in for AC adapter</span></li> <li class="a-spacing-mini"><span class="a-list-item">What\'s In the Box: Acer Aspire Laptop, AC Adapter, Power Cord</span></li> <li class="a-spacing-mini"><span class="a-list-item">Keyboard backlight not present on this model</span></li> </ul> </div>  </div> <div class="a-section aok-hidden" data-csa-c-content-id="voyager-product-details-jumplink" data-csa-c-id="twcewi-hu2ttu-4fs2bc-z2oear" data-csa-c-slot-id="voyager-product-details-jumplink" data-csa-c-type="link"> <span class="caretnext">›</span>  </div> </div> </div>\n</div>  </div>\n<div class="celwidget" data-cel-widget="depthInfoCard_1" data-csa-c-asin="B0BS4BP8FB" data-csa-c-content-id="depthInfoCard_1" data-csa-c-id="4dq6pw-hq7g0a-vgwwhu-7jyk44" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="depthInfoCard_1" data-csa-c-type="widget" data-feature-name="depthInfoCard_1" id="depthInfoCard_1">\n  <div class="a-section aok-hidden hoc-pill-content" id="hoc-depthInfoCard_1"> <div class="celwidget" data-cel-widget="depthInfoGrouping_1_feature_div" data-csa-c-asin="B0BS4BP8FB" data-csa-c-content-id="depthInfoGrouping_1" data-csa-c-id="ozcin4-o1qmni-yn9v4y-vyov2k" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="depthInfoGrouping_1_feature_div" ...
# Response: ```json
# {
#   "front_facing_camera": "Yes, HD front-facing camera with TNR (Temporal Noise Reduction) technology"
# }
# ```
# Time: 17810.22 ms
# ==============================================================================
# chunks_HSC :
# Chunks:  ['skip keyboard shortcuts move items use keyboards arrows amazoncom acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home mode electronics  buy new see product details add item cart return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option drop', 'leave ships amazoncom sold amazoncom spcsrf spendcsrf see product details add item cart always remove later return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option drop leave quantity quantity 1 add cart buy enhancements chose arent available seller add following enhancements purchase choose different seller cardname cardname available seller chose cardname', 'unavailable quantities greater maxquantity ships amazoncom ships amazoncom sold amazoncom sold amazoncom returns 30day refundreplacement item returned original condition full refund replacement within 30 days receipt clean buyx_offersx_dod_gifting_jsp_param_optimization_1084861 sim httpsissuesamazoncomissuesofxs2531 sim httpsissuesamazoncomissuesofxs2617 fix typo popvername occurrence fixed buyx_offersx_dod_gifting_jsp_param_optimization_1084861 cleaned favor t1 gift options gets template', 'gifting teams package files added use cases content type checkout add custom message gift receipt easy returns item giftwrapped add gift options checkout payment transaction secure work hard protect security privacy payment security system encrypts information transmission dont share credit card details thirdparty sellers dont sell information others support whats product support event product doesnt work expected need help using amazon offers free product support options live phonechat amazon', 'associate manufacturer contact information stepbystep troubleshooting guides help videos solving product issues help planet extending life products availability support options differ product country save used like new see product details add item cart ships macluvin sold macluvin spcsrf spendcsrf see product details add item cart always remove later add cart enhancements chose arent available seller add following enhancements purchase choose different seller cardname cardname available seller', 'chose cardname unavailable quantities greater maxquantity ships sold spcsrf spendcsrf add list added unable add item list please try sorry problem error retrieving wish lists please try sorry problem list unavailable spcsrf spendcsrf sellers amazon 9 8 7 6 5 4 10 videos video showcases product use video guides product setup video compares multiple products video shows product unpacked video player loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions selected', 'captions selected default selected modal window microsoft windows copilot acer america corporation image unavailable image available forcolor view video download roll image zoom video showcases product use video guides product setup video compares multiple products video shows product unpacked video player loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions selected 9 8 7 6 5 4 10 videos0 9 8 7 6 5 4 10 videos1 9 8 7 6 5 4 10 videos2 customer review microsoft windows copilot verified purchase earns', 'commissions verified purchase earns commissions ask rufus', 'amazons choice highlights highly rated wellpriced products available ship immediately amazons choice 4k bought past month see product details add item cart always remove later return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option dro ...
# Embeddings Shape:  (28, 768)
# Similar Chunks:  ['laptop ac adapter power cord', 'would like acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home mode share found lower price let us know although cant match every price reported well use feedback ensure prices remain competitive', 'maintain strong consistent wireless signal wifi 6 aka 80211ax 2x2 mumimo technology strategic slot antenna placement helps maximize portability wireless performance laptop']
# Response: ```json
# {
#   "front_facing_camera": "NAN"
# }
# ```
# Time: 7598.48 ms
# ==============================================================================
# Unstructured :
# Chunks:  ['› › › › buy new: see product details, add item cart.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! ships from: amazon.com sold by: amazon.com save used - like new see product details, add item cart. ships from: macluvin sold by: macluvin sellers amazon 9+ 8+ 7+ 6+ 5+ 4+ 10 videos', 'video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window. microsoft windows copilotacer america corporation', 'image unavailable image available forcolor: view video download roll image zoom video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window.', 'customer review: microsoft windows copilot acer america corporation verified purchase earns commissions verified purchase earns commissions ask rufus', 'acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode amazon\'s choice highlights highly rated, well-priced products available ship immediately. amazon\'s choice 4k+ bought past month see product details, add item cart. always remove later.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! see product details, add item cart. always remove later. available lower price may offer free prime shipping. brief content visible, double tap read full content.', 'full content visible, double tap read brief content. cpu: r3 7320u r3 7320u $299.99 7 percent savings$299.99 $321.99$321.99 stock r5 7520u see available options r7 5825u see available options a314-23p-r3qa see available options style: 15.6 inch / 8gb / 128gb 15.6 inch / 8gb / 128gb 14-inch / 8gb / 512gb 15.6 inch / 16gb / 512gb 15.6 inch touch / 16gb / 512gb', 'purchase options add-ons brief content visible, double tap read full content. full content visible, double tap read brief content. product details top highlights item details display processor memory ports & slots brand acer model name laptop screen size 15.6 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'item purposeful design: travel ease look great aspire\'s 3 thin, light design. ready-to-go performance: aspire 3 ready-to-go latest amd ryzen 3 7320u processor radeon graphics—ideal entire family, performance productivity core. visibly stunning: experience sharp details crisp colors 15.6" full hd ips display 16:9 aspect ratio narrow bezels.', 'internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.', 'wireless wi-fi 6 convenience: maintain strong, consistent wireless signal wi-fi 6 (aka 802.11ax) 2x2 mu-mimo technology. improved thermals: 78% increase fan surface area, enjoy improved thermal system additional 17% thermal capacity. allowing longer, efficient work sessions plugged in.', "ports accessories: 1 - usb type-c port usb ...
# Embeddings Shape:  (41, 768)
# Similar Chunks:  ['product warranty: warranty information product, please [pdf ] feedback would like acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode share: found lower price? let us know. although can\'t match every price reported, use feedback ensure prices remain competitive.', 'internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.', 'acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode amazon\'s choice highlights highly rated, well-priced products available ship immediately. amazon\'s choice 4k+ bought past month see product details, add item cart. always remove later.']
# Response: ```json
# {
#   "front_facing_camera": "yes"
# }
# ```
# Time: 7323.80 ms
# ==============================================================================

# %% [markdown]
# ## all-MiniLM-L6-v2

# %%
prompt("Extract the amount of RAM memory installed", model2, k=3)
# Out:
# No-Chunking: ```json
# {
#   "ram_memory_installed": "8 GB"
# }
# ```
# Time: 4197.03 ms
# ==============================================================================
# chunks_SC :
# Chunks:  ['<html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.25.1-2025-03-08" lang="en-us"><!-- sp:feature:head-start --><!-- sp:end-feature:head-close -->\n<!-- sp:feature:start-body -->\n<body class="a-m-us a-aui_72554-c a-aui_a11y_6_837773-c a-aui_killswitch_csa_logger_372963-t1 a-aui_pci_risk_banner_210084-c a-aui_template_weblab_cache_333406-c a-aui_tnr_v2_180836-c a-bw_aui_cxc_alert_measurement_1074111-c a-meter-animate"><div id="a-page"><!-- sp:end-feature:start-body -->\n<!-- sp:feature:csm:body-open -->\n\n\n<!-- sp:end-feature:csm:body-open -->\n<!-- sp:feature:nav-inline-js -->\n<!-- NAVYAAN JS -->\n\n\n\n\n\n<!-- sp:end-feature:nav-inline-js -->\n<!-- sp:feature:nav-skeleton -->\n<!-- sp:end-feature:nav-skeleton -->\n<!-- sp:feature:navbar -->\n<!--Pilu -->\n<!-- NAVYAAN-BACKUP -->\n<!-- navmet initial definition -->\n\n\n\n\n\n\n\n\n<nav aria-label="Shortcuts menu" class="nav-assistant" id="shortcut-menu" role="navigation" tabindex="-1">\n<h2 class="nav-assistant-heading nav-assistant-headers-font" id="nav-assistant-links-heading">Skip to</h2>\n\n\n<h2 class="nav-assistant-heading nav-assistant-headers-font font-color" id="shortcuts-heading">\n      Keyboard shortcuts\n  </h2>\n\n<div id="nav-assist-shortcut-help">\n<div class="shortcut-help-container">\n<div class="shortcut-help-item-container">\n\n<div class="help-text-container">\n<span class="shortcut-help-text font-color">To move between items, use your keyboard\'s up or down arrows.</span>\n</div>\n</div>\n</div>\n</div>\n</nav>\n\n\n\n\n\n\n\n\n<!-- sp:end-feature:navbar -->\n<!-- sp:feature:configured-sitewide-before-host-atf-assets -->\n\n<!-- sp:end-feature:configured-sitewide-before-host-atf-assets -->\n<!-- sp:feature:host-atf -->\n<title>Amazon.com: Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Full HD IPS Display | AMD Ryzen 3 7320U Quad-Core Processor | AMD Radeon Graphics | 8GB LPDDR5 | 128GB NVMe SSD | Wi-Fi 6 | Windows 11 Home in S Mode : Electronics</title>\n\n<div class="pc en_US" id="dp">\n\n<div class="a-container" id="dp-container" role="main">\n\n\n\n\n<div class="a-section" id="above-dp-container"> \n\n\n\n\n\n<div class="celwidget" data-cel-widget="desktop-breadcrumbs_feature_div" data-csa-c-asin="" data-csa-c-content-id="desktop-breadcrumbs" data-csa-c-id="nqlj00-f5qepk-6s20o-udmatk" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="desktop-breadcrumbs_feature_div" data-csa-c-type="widget" data-feature-name="desktop-breadcrumbs" id="desktop-breadcrumbs_feature_div">\n<div cel_widget_id="seo-breadcrumb-desktop-card_DetailPage_5" class="celwidget c-f" data-cel-widget="seo-breadcrumb-desktop-card_DetailPage_5" data-csa-c-content-id="DsUnknown" data-csa-c-id="yz0tuv-4rg0lg-rod6hk-f5lytl" data-csa-c-painter="seo-breadcrumb-desktop-card-cards" data-csa-c-slot-id="DsUnknown-6" data-csa-c-type="widget" data-csa-op-log-render=""><!--CardsClient--><div class="a-section a-spacing-none a-padding-medium" data-card-metrics-id="seo-breadcrumb-desktop-card_DetailPage_5" id="CardInstance5Jgd1gGrRUHVHs-h062CKA"><div class="a-subheader a-breadcrumb feature" data-cel-widget="wayfinding-breadcrumbs_feature_div" data-feature-name="wayfinding-breadcrumbs" id="wayfinding-breadcrumbs_feature_div"><ul class="a-unordered-list a-horizontal a-size-small"><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li></ul></div></div></div> </div>\n ...
# Embeddings Shape:  (16, 384)
# Similar Chunks:  ['<html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.25.1-2025-03-08" lang="en-us"><!-- sp:feature:head-start --><!-- sp:end-feature:head-close -->\n<!-- sp:feature:start-body -->\n<body class="a-m-us a-aui_72554-c a-aui_a11y_6_837773-c a-aui_killswitch_csa_logger_372963-t1 a-aui_pci_risk_banner_210084-c a-aui_template_weblab_cache_333406-c a-aui_tnr_v2_180836-c a-bw_aui_cxc_alert_measurement_1074111-c a-meter-animate"><div id="a-page"><!-- sp:end-feature:start-body -->\n<!-- sp:feature:csm:body-open -->\n\n\n<!-- sp:end-feature:csm:body-open -->\n<!-- sp:feature:nav-inline-js -->\n<!-- NAVYAAN JS -->\n\n\n\n\n\n<!-- sp:end-feature:nav-inline-js -->\n<!-- sp:feature:nav-skeleton -->\n<!-- sp:end-feature:nav-skeleton -->\n<!-- sp:feature:navbar -->\n<!--Pilu -->\n<!-- NAVYAAN-BACKUP -->\n<!-- navmet initial definition -->\n\n\n\n\n\n\n\n\n<nav aria-label="Shortcuts menu" class="nav-assistant" id="shortcut-menu" role="navigation" tabindex="-1">\n<h2 class="nav-assistant-heading nav-assistant-headers-font" id="nav-assistant-links-heading">Skip to</h2>\n\n\n<h2 class="nav-assistant-heading nav-assistant-headers-font font-color" id="shortcuts-heading">\n      Keyboard shortcuts\n  </h2>\n\n<div id="nav-assist-shortcut-help">\n<div class="shortcut-help-container">\n<div class="shortcut-help-item-container">\n\n<div class="help-text-container">\n<span class="shortcut-help-text font-color">To move between items, use your keyboard\'s up or down arrows.</span>\n</div>\n</div>\n</div>\n</div>\n</nav>\n\n\n\n\n\n\n\n\n<!-- sp:end-feature:navbar -->\n<!-- sp:feature:configured-sitewide-before-host-atf-assets -->\n\n<!-- sp:end-feature:configured-sitewide-before-host-atf-assets -->\n<!-- sp:feature:host-atf -->\n<title>Amazon.com: Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Full HD IPS Display | AMD Ryzen 3 7320U Quad-Core Processor | AMD Radeon Graphics | 8GB LPDDR5 | 128GB NVMe SSD | Wi-Fi 6 | Windows 11 Home in S Mode : Electronics</title>\n\n<div class="pc en_US" id="dp">\n\n<div class="a-container" id="dp-container" role="main">\n\n\n\n\n<div class="a-section" id="above-dp-container"> \n\n\n\n\n\n<div class="celwidget" data-cel-widget="desktop-breadcrumbs_feature_div" data-csa-c-asin="" data-csa-c-content-id="desktop-breadcrumbs" data-csa-c-id="nqlj00-f5qepk-6s20o-udmatk" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="desktop-breadcrumbs_feature_div" data-csa-c-type="widget" data-feature-name="desktop-breadcrumbs" id="desktop-breadcrumbs_feature_div">\n<div cel_widget_id="seo-breadcrumb-desktop-card_DetailPage_5" class="celwidget c-f" data-cel-widget="seo-breadcrumb-desktop-card_DetailPage_5" data-csa-c-content-id="DsUnknown" data-csa-c-id="yz0tuv-4rg0lg-rod6hk-f5lytl" data-csa-c-painter="seo-breadcrumb-desktop-card-cards" data-csa-c-slot-id="DsUnknown-6" data-csa-c-type="widget" data-csa-op-log-render=""><!--CardsClient--><div class="a-section a-spacing-none a-padding-medium" data-card-metrics-id="seo-breadcrumb-desktop-card_DetailPage_5" id="CardInstance5Jgd1gGrRUHVHs-h062CKA"><div class="a-subheader a-breadcrumb feature" data-cel-widget="wayfinding-breadcrumbs_feature_div" data-feature-name="wayfinding-breadcrumbs" id="wayfinding-breadcrumbs_feature_div"><ul class="a-unordered-list a-horizontal a-size-small"><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li></ul></div></div></div>  ...
# Response: ```json
# {
#   "RAM Memory Installed": "8 GB"
# }
# ```
# Time: 6530.92 ms
# ==============================================================================
# chunks_HSC :
# Chunks:  ['skip keyboard shortcuts move items use keyboards arrows amazoncom acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home mode electronics  buy new see product details add item cart return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option drop', 'leave ships amazoncom sold amazoncom spcsrf spendcsrf see product details add item cart always remove later return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option drop leave quantity quantity 1 add cart buy enhancements chose arent available seller add following enhancements purchase choose different seller cardname cardname available seller chose cardname', 'unavailable quantities greater maxquantity ships amazoncom ships amazoncom sold amazoncom sold amazoncom returns 30day refundreplacement item returned original condition full refund replacement within 30 days receipt clean buyx_offersx_dod_gifting_jsp_param_optimization_1084861 sim httpsissuesamazoncomissuesofxs2531 sim httpsissuesamazoncomissuesofxs2617 fix typo popvername occurrence fixed buyx_offersx_dod_gifting_jsp_param_optimization_1084861 cleaned favor t1 gift options gets template', 'gifting teams package files added use cases content type checkout add custom message gift receipt easy returns item giftwrapped add gift options checkout payment transaction secure work hard protect security privacy payment security system encrypts information transmission dont share credit card details thirdparty sellers dont sell information others support whats product support event product doesnt work expected need help using amazon offers free product support options live phonechat amazon', 'associate manufacturer contact information stepbystep troubleshooting guides help videos solving product issues help planet extending life products availability support options differ product country save used like new see product details add item cart ships macluvin sold macluvin spcsrf spendcsrf see product details add item cart always remove later add cart enhancements chose arent available seller add following enhancements purchase choose different seller cardname cardname available seller', 'chose cardname unavailable quantities greater maxquantity ships sold spcsrf spendcsrf add list added unable add item list please try sorry problem error retrieving wish lists please try sorry problem list unavailable spcsrf spendcsrf sellers amazon 9 8 7 6 5 4 10 videos video showcases product use video guides product setup video compares multiple products video shows product unpacked video player loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions selected', 'captions selected default selected modal window microsoft windows copilot acer america corporation image unavailable image available forcolor view video download roll image zoom video showcases product use video guides product setup video compares multiple products video shows product unpacked video player loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions selected 9 8 7 6 5 4 10 videos0 9 8 7 6 5 4 10 videos1 9 8 7 6 5 4 10 videos2 customer review microsoft windows copilot verified purchase earns', 'commissions verified purchase earns commissions ask rufus', 'amazons choice highlights highly rated wellpriced products available ship immediately amazons choice 4k bought past month see product details add item cart always remove later return item free offer easy convenient returns least one free return option shipping charges returns must comply returns policy go orders start return select preferred free shipping option dro ...
# Embeddings Shape:  (28, 384)
# Similar Chunks:  ['r3 7320u 29999 7 percent savings 29999 32199 32199 stock r5 7520u see available options r7 5825u see available options a31423pr3qa see available options style 156 inch 8gb 128gb 156 inch 8gb 128gb 14inch 8gb 512gb 156 inch 16gb 512gb 156 inch touch 16gb 512gb purchase options addons product details top highlights item details display processor memory ports slots brand acer model name laptop screen size 156 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'standing screen display size 156 inches screen resolution 1920 x 1080 pixels max screen resolution 1920x1080 processor 41 ghz ryzen_3 ram 8 gb lpddr5 memory speed 3200 mhz hard drive 128 gb ssd graphics coprocessor amd radeon graphics chipset brand amd card description integrated graphics card ram size 8 gb wireless type bluetooth 80211ax number usb 30 ports 3 average battery life hours 11 hours brand acer series laptop item model number nxkjbaa001 hardware platform pc operating system windows 11 item weight 392 pounds product dimensions 1429 x 074 x 935 inches item dimensions lxwxh 1429 x 074 x 935 inches color silver processor brand amd number processors 4 computer memory type ddr5 ram flash memory size 128 gb hard drive interface solid state optical drive type optical drive voltage 240 volts batteries 1 lithium ion batteries required included', 'item acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home mode recommendations try added cart add cart try added cart add cart try added cart add cart try added cart add cart try added cart add cart try added cart add cart price 7 29999 299 99 typical 32199 28824 288 24 9 34500 345 00 list 37999 40755 407 55 37200 372 00 29999 299 99 delivery get soon monday mar 17 get soon monday mar 17 get mar 14 17 get mar 19 21 get mar 17 19 get soon monday mar 17 customer ratings sold amazoncom choice electronicsserial numbers recorded jw deals serial numbers recorded futuretechsn recorded emmas market made usa amazoncom display size 156 inches 156 inches 156 inches 156 inches 156 inches 156 inches hard disk size 128 gb 128 gb 128 gb 512 gb 512 gb 128 gb computer memory size 8 gb 8 gb 8 gb 8 gb cpu manufacturer amd intel intel amd amd amd cpu speed 41 ghz 18 ghz 41 ghz 43 ghz 28 ghz 41 ghz cpu model number ryzen 3 7320u i3n305 i31115g4 amd ryzen 7 5700u r37320u operating system windows 11 windows 11 windows 11 windows 11 home windows 11 home windows 11 home ram tech lpddr5 lpddr5 ddr4 ddr4 lpddr5 lpddr5 graphics coprocessor amd radeon graphics intel uhd graphics intel uhd graphics amd radeon graphics amd radeon graphics amd ryzen 3 7320u gpu manufacturer amd intel intel intel amd amd wireless tech bluetooth wifi wifi bluetooth wifi bluetooth wifi wifi wifi bluetooth']
# Response: ```json
# {
#   "ram_memory_installed_size": "8 GB"
# }
# ```
# Time: 2574.65 ms
# ==============================================================================
# Unstructured :
# Chunks:  ['› › › › buy new: see product details, add item cart.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! ships from: amazon.com sold by: amazon.com save used - like new see product details, add item cart. ships from: macluvin sold by: macluvin sellers amazon 9+ 8+ 7+ 6+ 5+ 4+ 10 videos', 'video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window. microsoft windows copilotacer america corporation', 'image unavailable image available forcolor: view video download roll image zoom video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window.', 'customer review: microsoft windows copilot acer america corporation verified purchase earns commissions verified purchase earns commissions ask rufus', 'acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode amazon\'s choice highlights highly rated, well-priced products available ship immediately. amazon\'s choice 4k+ bought past month see product details, add item cart. always remove later.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! see product details, add item cart. always remove later. available lower price may offer free prime shipping. brief content visible, double tap read full content.', 'full content visible, double tap read brief content. cpu: r3 7320u r3 7320u $299.99 7 percent savings$299.99 $321.99$321.99 stock r5 7520u see available options r7 5825u see available options a314-23p-r3qa see available options style: 15.6 inch / 8gb / 128gb 15.6 inch / 8gb / 128gb 14-inch / 8gb / 512gb 15.6 inch / 16gb / 512gb 15.6 inch touch / 16gb / 512gb', 'purchase options add-ons brief content visible, double tap read full content. full content visible, double tap read brief content. product details top highlights item details display processor memory ports & slots brand acer model name laptop screen size 15.6 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'item purposeful design: travel ease look great aspire\'s 3 thin, light design. ready-to-go performance: aspire 3 ready-to-go latest amd ryzen 3 7320u processor radeon graphics—ideal entire family, performance productivity core. visibly stunning: experience sharp details crisp colors 15.6" full hd ips display 16:9 aspect ratio narrow bezels.', 'internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.', 'wireless wi-fi 6 convenience: maintain strong, consistent wireless signal wi-fi 6 (aka 802.11ax) 2x2 mu-mimo technology. improved thermals: 78% increase fan surface area, enjoy improved thermal system additional 17% thermal capacity. allowing longer, efficient work sessions plugged in.', "ports accessories: 1 - usb type-c port usb ...
# Embeddings Shape:  (41, 384)
# Similar Chunks:  ['purchase options add-ons brief content visible, double tap read full content. full content visible, double tap read brief content. product details top highlights item details display processor memory ports & slots brand acer model name laptop screen size 15.6 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'processor series ryzen 3 processor speed 4.1 ghz processor count 4 processor brand amd cpu model number ryzen 3 7320u ram memory installed 8 gb ram memory technology lpddr5 memory clock speed 3200 mhz ram memory maximum size 8 gb memory speed 2400 mhz ram type ddr5 ram cache memory installed size 4 total usb ports 2 hardware connectivity bluetooth number ports 5 total number hdmi ports 1', 'full content visible, double tap read brief content. cpu: r3 7320u r3 7320u $299.99 7 percent savings$299.99 $321.99$321.99 stock r5 7520u see available options r7 5825u see available options a314-23p-r3qa see available options style: 15.6 inch / 8gb / 128gb 15.6 inch / 8gb / 128gb 14-inch / 8gb / 512gb 15.6 inch / 16gb / 512gb 15.6 inch touch / 16gb / 512gb']
# Response: ```json
# {
#   "ram_memory_installed_size": "8 GB"
# }
# ```
# Time: 2798.62 ms
# ==============================================================================

# %%
prompt("Extract the laptop price", model2, k=3)
# Out:
# No-Chunking: ```json
# {
#   "laptop_price": "$299.99"
# }
# ```
# Time: 6167.17 ms
# ==============================================================================
# chunks_SC :
# Chunks:  ['<html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.25.1-2025-03-08" lang="en-us"><!-- sp:feature:head-start --><!-- sp:end-feature:head-close -->\n<!-- sp:feature:start-body -->\n<body class="a-m-us a-aui_72554-c a-aui_a11y_6_837773-c a-aui_killswitch_csa_logger_372963-t1 a-aui_pci_risk_banner_210084-c a-aui_template_weblab_cache_333406-c a-aui_tnr_v2_180836-c a-bw_aui_cxc_alert_measurement_1074111-c a-meter-animate"><div id="a-page"><!-- sp:end-feature:start-body -->\n<!-- sp:feature:csm:body-open -->\n\n\n<!-- sp:end-feature:csm:body-open -->\n<!-- sp:feature:nav-inline-js -->\n<!-- NAVYAAN JS -->\n\n\n\n\n\n<!-- sp:end-feature:nav-inline-js -->\n<!-- sp:feature:nav-skeleton -->\n<!-- sp:end-feature:nav-skeleton -->\n<!-- sp:feature:navbar -->\n<!--Pilu -->\n<!-- NAVYAAN-BACKUP -->\n<!-- navmet initial definition -->\n\n\n\n\n\n\n\n\n<nav aria-label="Shortcuts menu" class="nav-assistant" id="shortcut-menu" role="navigation" tabindex="-1">\n<h2 class="nav-assistant-heading nav-assistant-headers-font" id="nav-assistant-links-heading">Skip to</h2>\n\n\n<h2 class="nav-assistant-heading nav-assistant-headers-font font-color" id="shortcuts-heading">\n      Keyboard shortcuts\n  </h2>\n\n<div id="nav-assist-shortcut-help">\n<div class="shortcut-help-container">\n<div class="shortcut-help-item-container">\n\n<div class="help-text-container">\n<span class="shortcut-help-text font-color">To move between items, use your keyboard\'s up or down arrows.</span>\n</div>\n</div>\n</div>\n</div>\n</nav>\n\n\n\n\n\n\n\n\n<!-- sp:end-feature:navbar -->\n<!-- sp:feature:configured-sitewide-before-host-atf-assets -->\n\n<!-- sp:end-feature:configured-sitewide-before-host-atf-assets -->\n<!-- sp:feature:host-atf -->\n<title>Amazon.com: Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Full HD IPS Display | AMD Ryzen 3 7320U Quad-Core Processor | AMD Radeon Graphics | 8GB LPDDR5 | 128GB NVMe SSD | Wi-Fi 6 | Windows 11 Home in S Mode : Electronics</title>\n\n<div class="pc en_US" id="dp">\n\n<div class="a-container" id="dp-container" role="main">\n\n\n\n\n<div class="a-section" id="above-dp-container"> \n\n\n\n\n\n<div class="celwidget" data-cel-widget="desktop-breadcrumbs_feature_div" data-csa-c-asin="" data-csa-c-content-id="desktop-breadcrumbs" data-csa-c-id="nqlj00-f5qepk-6s20o-udmatk" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="desktop-breadcrumbs_feature_div" data-csa-c-type="widget" data-feature-name="desktop-breadcrumbs" id="desktop-breadcrumbs_feature_div">\n<div cel_widget_id="seo-breadcrumb-desktop-card_DetailPage_5" class="celwidget c-f" data-cel-widget="seo-breadcrumb-desktop-card_DetailPage_5" data-csa-c-content-id="DsUnknown" data-csa-c-id="yz0tuv-4rg0lg-rod6hk-f5lytl" data-csa-c-painter="seo-breadcrumb-desktop-card-cards" data-csa-c-slot-id="DsUnknown-6" data-csa-c-type="widget" data-csa-op-log-render=""><!--CardsClient--><div class="a-section a-spacing-none a-padding-medium" data-card-metrics-id="seo-breadcrumb-desktop-card_DetailPage_5" id="CardInstance5Jgd1gGrRUHVHs-h062CKA"><div class="a-subheader a-breadcrumb feature" data-cel-widget="wayfinding-breadcrumbs_feature_div" data-feature-name="wayfinding-breadcrumbs" id="wayfinding-breadcrumbs_feature_div"><ul class="a-unordered-list a-horizontal a-size-small"><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li></ul></div></div></div> </div>\n ...
# Embeddings Shape:  (16, 384)
# Similar Chunks:  ['Any returned computer that is damaged through customer misuse, is missing parts, or is in unsellable condition due to customer tampering will result in the customer being charged a higher restocking fee based on the condition of the product. Amazon.com will not accept returns of any desktop or notebook computer more than 30 days after you receive the shipment. New, used, and refurbished products purchased from Marketplace vendors are subject to the returns policy of the individual vendor.</span> </div> <div class="a-section table-padding">    Product Warranty: For warranty information about this product, please <span class="a-color-secondary"> [PDF ] </span> </div> </div> </div>\n</div> <div class="a-row"> <div class="a-section"> <h1 class="a-size-medium a-spacing-small secHeader"> Feedback </h1> <div class="a-section table-padding"> <div class="a-row">                                             \n<div>\n<div class="detailPageWidgetBlock" id="pricingFeedbackDiv">\n<span class="a-declarative" data-action="pricingFeedback-modal-button" data-pricingfeedback-modal-button="{}"> Would you like to  \n</span> </div>\n<div class="a-popover-preload" id="a-popover-pricingFeedback-modal-content"> <div class="contentContainer" id="pricingFeedback_contentContainer" style="overflow: auto;">\n<div id="feedbackForm" style="display: none;">\n<div id="pricingFeedback_titleBar">\n<div class="container" style="display: flex;">\n\n<div style="flex-grow: 1;">\n<p tabindex="0">Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Full HD IPS Display | AMD Ryzen 3 7320U Quad-Core Processor | AMD Radeon Graphics | 8GB LPDDR5 | 128GB NVMe SSD | Wi-Fi 6 | Windows 11 Home in S Mode</p>\n<p id="permalink">\n<b>Share:\n                                    </b>\n</p>\n</div>\n</div>\n</div>\n\n\n<p tabindex="0">Found a lower price? Let us know. Although we can\'t match every price reported, we\'ll use your feedback to ensure that our prices remain competitive.</p>\n<h2 tabindex="0">Where did you see a lower price?</h2>\n<p id="note1" style="display: none" tabindex="0">Fields with an asterisk <span aria-hidden="true" class="asterisk">*</span> are required</p>\n<div class="priceavailability">\n<fieldset aria-labelledby="PriceAvailabilitySection" role="radiogroup">\n<legend class="visually-hidden">Price Availability</legend>\n<fieldset aria-labelledby="OnlinePriceAvailabilitySection" role="group">\n<legend>\n<div id="onlineRadioContainer" style="display: flex">\n\n<label for="pricingFeedback_onlineRadio">Website (Online)</label>\n</div>\n</legend>\n<div class="grid-container" id="pricingFeedback_onlineInput">\n<div class="grid-row">\n<label class="grid-label" for="onlineUrl" id="onlineUrlLabel">URL <span class="asterisk">*</span>:</label>\n\n</div>\n<div class="grid-row">\n<label class="grid-label" for="onlinePriceRaw" id="onlinePriceRawLabel">Price\n                                        ($)\n                                        <span class="asterisk">*</span>:\n                                    </label>\n\n</div>\n<div class="grid-row">\n<label class="grid-label" for="onlineShippingRaw" id="onlineShippingRawLabel">Shipping cost\n                                        ($):\n                                    </label>\n\n</div>\n<div aria-labelledby="onlineCalendarLabel" class="grid-row" role="group">\n<label class="grid-label" for="onlineCalendar" id="onlineCalendarLabel"> Date of the price\n                                        (MM/DD/YYYY):</label>\n<div class="a-fixed-left-grid-col a-col-right grid-input">\n<div>\n<div id="onlineCalendar">\n\n<div class="firstDelimiter" style="flex: 1; float: left; display: inline-block;">\n                                                    /\n                                                </div>\n\n<div class="secondDelimiter" style="flex: 1; float: left; display: inline-block;">\n                                                    /\n                                                </div>\n\n</div> ...
# Response: ```json
# {
#   "laptop_price": "$299.99"
# }
# ```
# Time: 7678.43 ms
# ==============================================================================
# chunks_HSC :
# Chunks:  ['skip to keyboard shortcuts to move between items use your keyboards up or down arrows amazoncom acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home in s mode electronics  buy new to see product details add this item to your cart return this item for free we offer easy convenient returns with at least one free return option no shipping charges all returns must comply with', 'our returns policy go to your orders and start the return select your preferred free shipping option drop off and leave ships from amazoncom sold by amazoncom spcsrf spendcsrf to see product details add this item to your cart you can always remove it later return this item for free we offer easy convenient returns with at least one free return option no shipping charges all returns must comply with our returns policy go to your orders and start the return select your preferred free shipping', 'option drop off and leave quantity quantity 1 add to cart buy now enhancements you chose arent available for this seller to add the following enhancements to your purchase choose a different seller cardname cardname not available for the seller you chose cardname unavailable for quantities greater than maxquantity ships from amazoncom ships from amazoncom sold by amazoncom sold by amazoncom returns 30day refundreplacement this item can be returned in its original condition for a full refund or', 'replacement within 30 days of receipt clean up buyx_offersx_dod_gifting_jsp_param_optimization_1084861 sim httpsissuesamazoncomissuesofxs2531 sim httpsissuesamazoncomissuesofxs2617 to fix typo in popvername this occurrence should be fixed if buyx_offersx_dod_gifting_jsp_param_optimization_1084861 is cleaned up in favor of t1 gift options gets the template from gifting teams package other files will be added here for other use cases with same content type at checkout you can add a custom message', 'a gift receipt for easy returns and have the item giftwrapped add gift options at checkout payment your transaction is secure we work hard to protect your security and privacy our payment security system encrypts your information during transmission we dont share your credit card details with thirdparty sellers and we dont sell your information to others support whats product support in the event your product doesnt work as expected or you need help using it amazon offers free product support', 'options such as live phonechat with an amazon associate manufacturer contact information stepbystep troubleshooting guides and help videos by solving product issues we help the planet by extending the life of products availability of support options differ by product and country save with used like new to see product details add this item to your cart ships from macluvin sold by macluvin spcsrf spendcsrf to see product details add this item to your cart you can always remove it later add to', 'cart enhancements you chose arent available for this seller to add the following enhancements to your purchase choose a different seller cardname cardname not available for the seller you chose cardname unavailable for quantities greater than maxquantity ships from and sold by spcsrf spendcsrf add to list added to unable to add item to list please try again sorry there was a problem there was an error retrieving your wish lists please try again sorry there was a problem list unavailable spcsrf', 'spendcsrf other sellers on amazon 9 8 7 6 5 4 10 videos the video showcases the product in use the video guides you through product setup the video compares multiple products the video shows the product being unpacked video player is loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions off selected captions off selected default selected this is a modal window microsoft windows copilot acer america corporation image unavailable image not  ...
# Embeddings Shape:  (29, 384)
# Similar Chunks:  ['would you like to acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home in s mode share found a lower price let us know although we cant match every price reported well use your feedback to ensure that our prices remain competitive', 'this item acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home in s mode 29999 299 99 get it as soon as monday mar 17 in stock ships from and sold by amazoncom 1397 13 97 get it as soon as monday mar 17 in stock sold by priority sales inc and ships from amazon fulfillment 995 9 95 get it as soon as monday mar 17 in stock sold by booeudillc and ships from amazon fulfillment total', 'this item to your cart you can always remove it later available at a lower price from that may not offer free prime shipping cpu r3 7320u r3 7320u 29999 with 7 percent savings 29999 32199 32199 in stock r5 7520u see available options r7 5825u see available options a31423pr3qa see available options style 156 inch 8gb 128gb 156 inch 8gb 128gb 14inch 8gb 512gb 156 inch 16gb 512gb 156 inch touch 16gb 512gb purchase options and addons product details top highlights item details display processor memory ports slots brand acer model name laptop screen size 156 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 s special feature backlit keyboard graphics card description integrated']
# Response: ```json
# {
#   "laptop_price": "29999"
# }
# ```
# Time: 3147.84 ms
# ==============================================================================
# Unstructured :
# Chunks:  ['› › › › buy new: see product details, add item cart.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! ships from: amazon.com sold by: amazon.com save used - like new see product details, add item cart. ships from: macluvin sold by: macluvin sellers amazon 9+ 8+ 7+ 6+ 5+ 4+ 10 videos', 'video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window. microsoft windows copilotacer america corporation', 'image unavailable image available forcolor: view video download roll image zoom video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window.', 'customer review: microsoft windows copilot acer america corporation verified purchase earns commissions verified purchase earns commissions ask rufus', 'acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode amazon\'s choice highlights highly rated, well-priced products available ship immediately. amazon\'s choice 4k+ bought past month see product details, add item cart. always remove later.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! see product details, add item cart. always remove later. available lower price may offer free prime shipping. brief content visible, double tap read full content.', 'full content visible, double tap read brief content. cpu: r3 7320u r3 7320u $299.99 7 percent savings$299.99 $321.99$321.99 stock r5 7520u see available options r7 5825u see available options a314-23p-r3qa see available options style: 15.6 inch / 8gb / 128gb 15.6 inch / 8gb / 128gb 14-inch / 8gb / 512gb 15.6 inch / 16gb / 512gb 15.6 inch touch / 16gb / 512gb', 'purchase options add-ons brief content visible, double tap read full content. full content visible, double tap read brief content. product details top highlights item details display processor memory ports & slots brand acer model name laptop screen size 15.6 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'item purposeful design: travel ease look great aspire\'s 3 thin, light design. ready-to-go performance: aspire 3 ready-to-go latest amd ryzen 3 7320u processor radeon graphics—ideal entire family, performance productivity core. visibly stunning: experience sharp details crisp colors 15.6" full hd ips display 16:9 aspect ratio narrow bezels.', 'internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.', 'wireless wi-fi 6 convenience: maintain strong, consistent wireless signal wi-fi 6 (aka 802.11ax) 2x2 mu-mimo technology. improved thermals: 78% increase fan surface area, enjoy improved thermal system additional 17% thermal capacity. allowing longer, efficient work sessions plugged in.', "ports accessories: 1 - usb type-c port usb ...
# Embeddings Shape:  (41, 384)
# Similar Chunks:  ['frequently bought together item: acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode $299.99$299.99 get soon monday, mar 17 stock ships sold amazon.com. $13.97$13.97 get soon monday, mar 17 stock sold priority sales inc ships amazon fulfillment. $9.95$9.95 get soon monday, mar 17', 'product warranty: warranty information product, please [pdf ] feedback would like acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode share: found lower price? let us know. although can\'t match every price reported, use feedback ensure prices remain competitive.', 'brand \u200eacer series \u200elaptop item model number \u200enx.kjbaa.001 hardware platform \u200epc operating system \u200ewindows 11 item weight \u200e3.92 pounds product dimensions \u200e14.29 x 0.74 x 9.35 inches item dimensions lxwxh \u200e14.29 x 0.74 x 9.35 inches color \u200esilver processor brand \u200eamd number processors \u200e4 computer memory type \u200eddr5 ram flash memory size \u200e128 gb hard drive interface \u200esolid state optical drive type \u200eno optical drive voltage \u200e240 volts batteries \u200e1 lithium ion batteries required. (included)']
# Response: ```json
# {
#   "laptop_price": "299.99"
# }
# ```
# Time: 2856.46 ms
# ==============================================================================

# %%
prompt("Does the laptop has front camera ?", model2, k=3)
# Out:
# No-Chunking: ```json
# {
#   "front_camera": "Yes"
# }
# ```
# Time: 4620.98 ms
# ==============================================================================
# chunks_SC :
# Chunks:  ['<html class="a-js a-audio a-video a-canvas a-svg a-drag-drop a-geolocation a-history a-webworker a-autofocus a-input-placeholder a-textarea-placeholder a-local-storage a-gradients a-transform3d a-touch-scrolling a-text-shadow a-text-stroke a-box-shadow a-border-radius a-border-image a-opacity a-transform a-transition null" data-19ax5a9jf="dingo" data-aui-build-date="3.25.1-2025-03-08" lang="en-us"><!-- sp:feature:head-start --><!-- sp:end-feature:head-close -->\n<!-- sp:feature:start-body -->\n<body class="a-m-us a-aui_72554-c a-aui_a11y_6_837773-c a-aui_killswitch_csa_logger_372963-t1 a-aui_pci_risk_banner_210084-c a-aui_template_weblab_cache_333406-c a-aui_tnr_v2_180836-c a-bw_aui_cxc_alert_measurement_1074111-c a-meter-animate"><div id="a-page"><!-- sp:end-feature:start-body -->\n<!-- sp:feature:csm:body-open -->\n\n\n<!-- sp:end-feature:csm:body-open -->\n<!-- sp:feature:nav-inline-js -->\n<!-- NAVYAAN JS -->\n\n\n\n\n\n<!-- sp:end-feature:nav-inline-js -->\n<!-- sp:feature:nav-skeleton -->\n<!-- sp:end-feature:nav-skeleton -->\n<!-- sp:feature:navbar -->\n<!--Pilu -->\n<!-- NAVYAAN-BACKUP -->\n<!-- navmet initial definition -->\n\n\n\n\n\n\n\n\n<nav aria-label="Shortcuts menu" class="nav-assistant" id="shortcut-menu" role="navigation" tabindex="-1">\n<h2 class="nav-assistant-heading nav-assistant-headers-font" id="nav-assistant-links-heading">Skip to</h2>\n\n\n<h2 class="nav-assistant-heading nav-assistant-headers-font font-color" id="shortcuts-heading">\n      Keyboard shortcuts\n  </h2>\n\n<div id="nav-assist-shortcut-help">\n<div class="shortcut-help-container">\n<div class="shortcut-help-item-container">\n\n<div class="help-text-container">\n<span class="shortcut-help-text font-color">To move between items, use your keyboard\'s up or down arrows.</span>\n</div>\n</div>\n</div>\n</div>\n</nav>\n\n\n\n\n\n\n\n\n<!-- sp:end-feature:navbar -->\n<!-- sp:feature:configured-sitewide-before-host-atf-assets -->\n\n<!-- sp:end-feature:configured-sitewide-before-host-atf-assets -->\n<!-- sp:feature:host-atf -->\n<title>Amazon.com: Acer Aspire 3 A315-24P-R7VH Slim Laptop | 15.6" Full HD IPS Display | AMD Ryzen 3 7320U Quad-Core Processor | AMD Radeon Graphics | 8GB LPDDR5 | 128GB NVMe SSD | Wi-Fi 6 | Windows 11 Home in S Mode : Electronics</title>\n\n<div class="pc en_US" id="dp">\n\n<div class="a-container" id="dp-container" role="main">\n\n\n\n\n<div class="a-section" id="above-dp-container"> \n\n\n\n\n\n<div class="celwidget" data-cel-widget="desktop-breadcrumbs_feature_div" data-csa-c-asin="" data-csa-c-content-id="desktop-breadcrumbs" data-csa-c-id="nqlj00-f5qepk-6s20o-udmatk" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="desktop-breadcrumbs_feature_div" data-csa-c-type="widget" data-feature-name="desktop-breadcrumbs" id="desktop-breadcrumbs_feature_div">\n<div cel_widget_id="seo-breadcrumb-desktop-card_DetailPage_5" class="celwidget c-f" data-cel-widget="seo-breadcrumb-desktop-card_DetailPage_5" data-csa-c-content-id="DsUnknown" data-csa-c-id="yz0tuv-4rg0lg-rod6hk-f5lytl" data-csa-c-painter="seo-breadcrumb-desktop-card-cards" data-csa-c-slot-id="DsUnknown-6" data-csa-c-type="widget" data-csa-op-log-render=""><!--CardsClient--><div class="a-section a-spacing-none a-padding-medium" data-card-metrics-id="seo-breadcrumb-desktop-card_DetailPage_5" id="CardInstance5Jgd1gGrRUHVHs-h062CKA"><div class="a-subheader a-breadcrumb feature" data-cel-widget="wayfinding-breadcrumbs_feature_div" data-feature-name="wayfinding-breadcrumbs" id="wayfinding-breadcrumbs_feature_div"><ul class="a-unordered-list a-horizontal a-size-small"><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li><li class="a-breadcrumb-divider"><span class="a-list-item a-color-tertiary">›</span></li></ul></div></div></div> </div>\n ...
# Embeddings Shape:  (16, 384)
# Similar Chunks:  ['This Aspire 3 can tackle any job no matter how complex. Creativity soars to new heights with sharp, crisp visuals showcased on the 15.6" Full HD IPS screen, while the thin bezel provides you with more space to work with wherever inspiration strikes. It’s the perfect companion to take with you wherever you go With Windows 11 Home in S mode, you’ll experience fast start-ups, a familiar yet expanded Start menu, and great new ways to get stuff done.', '</span></li> <li class="a-spacing-mini"><span class="a-list-item"> Visibly Stunning: Experience sharp details and crisp colors on the 15.6" Full HD IPS display with 16:9 aspect ratio and narrow bezels. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Internal Specifications: 8GB LPDDR5 Onboard Memory; 128GB NVMe solid-state drive storage to store your files and media  </span></li> <li class="a-spacing-mini"><span class="a-list-item"> The HD front-facing camera uses Acer’s TNR (Temporal Noise Reduction) technology for high-quality imagery in low-light conditions. Acer PurifiedVoice technology with AI Noise Reduction filters out any extra sound for clear communication over online meetings. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Wireless Wi-Fi 6 Convenience: Maintain a strong, consistent wireless signal with Wi-Fi 6 (aka 802.11ax) and 2x2 MU-MIMO technology. </span></li> <li class="a-spacing-mini"><span class="a-list-item"> Improved Thermals: With a 78% increase in fan surface area, enjoy an improved thermal system and an additional 17% thermal capacity. Allowing for longer, more efficient work sessions while not plugged in. </span></li> </ul> <!-- Loading EDP related metadata -->\n<div class="a-row a-expander-container a-expander-inline-container"> <div class="a-expander-content a-expander-extend-content" data-expanded="false" style="display:none"> <ul class="a-unordered-list a-vertical a-spacing-none"> <li class="a-spacing-mini"><span class="a-list-item">Ports For All Your Accessories: 1 - USB Type-C Port USB 3.2 Gen 2 (up to 10 Gbps) DisplayPort over USB Type-C &amp; USB Charging, 2 - USB 3.2 Gen 1 Ports, 1 - HDMI 2.1 Port with HDCP support, 1 - Headphone/Speaker/Line-Out Jack, DC-in for AC adapter</span></li> <li class="a-spacing-mini"><span class="a-list-item">What\'s In the Box: Acer Aspire Laptop, AC Adapter, Power Cord</span></li> <li class="a-spacing-mini"><span class="a-list-item">Keyboard backlight not present on this model</span></li> </ul> </div>  </div> <div class="a-section aok-hidden" data-csa-c-content-id="voyager-product-details-jumplink" data-csa-c-id="twcewi-hu2ttu-4fs2bc-z2oear" data-csa-c-slot-id="voyager-product-details-jumplink" data-csa-c-type="link"> <span class="caretnext">›</span>  </div> </div> </div>\n</div>  </div>\n<div class="celwidget" data-cel-widget="depthInfoCard_1" data-csa-c-asin="B0BS4BP8FB" data-csa-c-content-id="depthInfoCard_1" data-csa-c-id="4dq6pw-hq7g0a-vgwwhu-7jyk44" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="depthInfoCard_1" data-csa-c-type="widget" data-feature-name="depthInfoCard_1" id="depthInfoCard_1">\n  <div class="a-section aok-hidden hoc-pill-content" id="hoc-depthInfoCard_1"> <div class="celwidget" data-cel-widget="depthInfoGrouping_1_feature_div" data-csa-c-asin="B0BS4BP8FB" data-csa-c-content-id="depthInfoGrouping_1" data-csa-c-id="ozcin4-o1qmni-yn9v4y-vyov2k" data-csa-c-is-in-initial-active-row="false" data-csa-c-slot-id="depthInfoGrouping_1_feature_div" data-csa-c-type="widget" data-feature-name="depthInfoGrouping_1" id="depthInfoGrouping_1_feature_div">\n<div class="a-section" id="productDetails_sectionTables_depthLeftSections"> <div class="a-section a-spacing-base"> <table class="a-keyvalue prodDetTable" role="presentation"> <tbody><tr> <th class="a-color-secondary a-size-base prodDetSectionEntry"> Brand </th> <td class="a-size-base prodDetAttrValue"> acer </td> </tr> <tr> <th class="a-color-secondary a-size-base prodDetSectionEntry"> Mode ...
# Response: ```json
# {
#   "front_camera": "Yes, it has an HD front-facing camera"
# }
# ```
# Time: 8210.39 ms
# ==============================================================================
# chunks_HSC :
# Chunks:  ['skip to keyboard shortcuts to move between items use your keyboards up or down arrows amazoncom acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home in s mode electronics  buy new to see product details add this item to your cart return this item for free we offer easy convenient returns with at least one free return option no shipping charges all returns must comply with', 'our returns policy go to your orders and start the return select your preferred free shipping option drop off and leave ships from amazoncom sold by amazoncom spcsrf spendcsrf to see product details add this item to your cart you can always remove it later return this item for free we offer easy convenient returns with at least one free return option no shipping charges all returns must comply with our returns policy go to your orders and start the return select your preferred free shipping', 'option drop off and leave quantity quantity 1 add to cart buy now enhancements you chose arent available for this seller to add the following enhancements to your purchase choose a different seller cardname cardname not available for the seller you chose cardname unavailable for quantities greater than maxquantity ships from amazoncom ships from amazoncom sold by amazoncom sold by amazoncom returns 30day refundreplacement this item can be returned in its original condition for a full refund or', 'replacement within 30 days of receipt clean up buyx_offersx_dod_gifting_jsp_param_optimization_1084861 sim httpsissuesamazoncomissuesofxs2531 sim httpsissuesamazoncomissuesofxs2617 to fix typo in popvername this occurrence should be fixed if buyx_offersx_dod_gifting_jsp_param_optimization_1084861 is cleaned up in favor of t1 gift options gets the template from gifting teams package other files will be added here for other use cases with same content type at checkout you can add a custom message', 'a gift receipt for easy returns and have the item giftwrapped add gift options at checkout payment your transaction is secure we work hard to protect your security and privacy our payment security system encrypts your information during transmission we dont share your credit card details with thirdparty sellers and we dont sell your information to others support whats product support in the event your product doesnt work as expected or you need help using it amazon offers free product support', 'options such as live phonechat with an amazon associate manufacturer contact information stepbystep troubleshooting guides and help videos by solving product issues we help the planet by extending the life of products availability of support options differ by product and country save with used like new to see product details add this item to your cart ships from macluvin sold by macluvin spcsrf spendcsrf to see product details add this item to your cart you can always remove it later add to', 'cart enhancements you chose arent available for this seller to add the following enhancements to your purchase choose a different seller cardname cardname not available for the seller you chose cardname unavailable for quantities greater than maxquantity ships from and sold by spcsrf spendcsrf add to list added to unable to add item to list please try again sorry there was a problem there was an error retrieving your wish lists please try again sorry there was a problem list unavailable spcsrf', 'spendcsrf other sellers on amazon 9 8 7 6 5 4 10 videos the video showcases the product in use the video guides you through product setup the video compares multiple products the video shows the product being unpacked video player is loading current time 000 duration 031 loaded 000 stream type remaining time 031 chapters descriptions off selected captions off selected default selected this is a modal window microsoft windows copilot acer america corporation image unavailable image not  ...
# Embeddings Shape:  (29, 384)
# Similar Chunks:  ['this item to your cart you can always remove it later available at a lower price from that may not offer free prime shipping cpu r3 7320u r3 7320u 29999 with 7 percent savings 29999 32199 32199 in stock r5 7520u see available options r7 5825u see available options a31423pr3qa see available options style 156 inch 8gb 128gb 156 inch 8gb 128gb 14inch 8gb 512gb 156 inch 16gb 512gb 156 inch touch 16gb 512gb purchase options and addons product details top highlights item details display processor memory ports slots brand acer model name laptop screen size 156 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 s special feature backlit keyboard graphics card description integrated', 'purposeful design travel with ease and look great doing it with the aspires 3 thin light design readytogo performance the aspire 3 is readytogo with the latest amd ryzen 3 7320u processor with radeon graphicsideal for the entire family with performance and productivity at the core visibly stunning experience sharp details and crisp colors on the 156 full hd ips display with 169 aspect ratio and narrow bezels internal specifications 8gb lpddr5 onboard memory 128gb nvme solidstate drive storage to store your files and media the hd frontfacing camera uses acers tnr temporal noise reduction technology for highquality imagery in lowlight conditions acer purifiedvoice technology with ai noise reduction filters out any extra sound for clear communication over online meetings wireless wifi 6 convenience maintain a strong consistent wireless signal with wifi 6 aka 80211ax and 2x2 mumimo technology improved thermals with a 78 increase in fan surface area enjoy an improved thermal system and an additional 17 thermal capacity allowing for longer more efficient work sessions while not plugged in ports for all your accessories 1 usb typec port usb 32 gen 2 up to 10 gbps displayport over usb typec usb charging 2 usb 32 gen 1 ports 1 hdmi 21 port with hdcp support 1 headphonespeakerlineout jack dcin for ac adapter whats in the box acer aspire laptop ac adapter power cord keyboard backlight not present on this model brand acer model name laptop model year 2023 model number nxkjbaa001 builtin media laptop power cord ac adapter manufacturer acer upc 195133155014 customer reviews 42 out of 5 stars best sellers rank 26 in computers accessories 2 in asin b0bs4bp8fb screen size 156 inches resolution 1080p native resolution 1920 x 1080 pixels display type lcd display resolution maximum 1920x1080 display technology lcd has color screen yes screen finish matte processor series ryzen 3 processor speed 41 ghz processor count 4 processor brand amd cpu model number ryzen 3 7320u ram memory installed 8 gb ram memory technology lpddr5 memory clock speed 3200 mhz ram memory maximum size 8 gb memory speed 2400 mhz ram type ddr5 ram cache memory installed size 4 total usb ports 2 hardware connectivity bluetooth number of ports 5 total number of hdmi ports 1', 'this item acer aspire 3 a31524pr7vh slim laptop 156 full hd ips display amd ryzen 3 7320u quadcore processor amd radeon graphics 8gb lpddr5 128gb nvme ssd wifi 6 windows 11 home in s mode 29999 299 99 get it as soon as monday mar 17 in stock ships from and sold by amazoncom 1397 13 97 get it as soon as monday mar 17 in stock sold by priority sales inc and ships from amazon fulfillment 995 9 95 get it as soon as monday mar 17 in stock sold by booeudillc and ships from amazon fulfillment total']
# Response: ```json
# {
#   "front_camera": "yes, hd frontfacing camera uses acers tnr temporal noise reduction technology"
# }
# ```
# Time: 2968.70 ms
# ==============================================================================
# Unstructured :
# Chunks:  ['› › › › buy new: see product details, add item cart.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! ships from: amazon.com sold by: amazon.com save used - like new see product details, add item cart. ships from: macluvin sold by: macluvin sellers amazon 9+ 8+ 7+ 6+ 5+ 4+ 10 videos', 'video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window. microsoft windows copilotacer america corporation', 'image unavailable image available forcolor: view video download roll image zoom video showcases product use.the video guides product setup.the video compares multiple products.the video shows product unpacked. video player loading. current time 0:00 duration 0:31 loaded: 0.00% 0:00 stream type live remaining time -0:31 1x chapters descriptions off, selected captions off, selected default, selected modal window.', 'customer review: microsoft windows copilot acer america corporation verified purchase earns commissions verified purchase earns commissions ask rufus', 'acer aspire 3 a315-24p-r7vh slim laptop | 15.6" full hd ips display | amd ryzen 3 7320u quad-core processor | amd radeon graphics | 8gb lpddr5 | 128gb nvme ssd | wi-fi 6 | windows 11 home mode amazon\'s choice highlights highly rated, well-priced products available ship immediately. amazon\'s choice 4k+ bought past month see product details, add item cart. always remove later.', 'return item free offer easy, convenient returns least one free return option: shipping charges. returns must comply returns policy. go orders start return select preferred free shipping option drop leave! see product details, add item cart. always remove later. available lower price may offer free prime shipping. brief content visible, double tap read full content.', 'full content visible, double tap read brief content. cpu: r3 7320u r3 7320u $299.99 7 percent savings$299.99 $321.99$321.99 stock r5 7520u see available options r7 5825u see available options a314-23p-r3qa see available options style: 15.6 inch / 8gb / 128gb 15.6 inch / 8gb / 128gb 14-inch / 8gb / 512gb 15.6 inch / 16gb / 512gb 15.6 inch touch / 16gb / 512gb', 'purchase options add-ons brief content visible, double tap read full content. full content visible, double tap read brief content. product details top highlights item details display processor memory ports & slots brand acer model name laptop screen size 15.6 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'item purposeful design: travel ease look great aspire\'s 3 thin, light design. ready-to-go performance: aspire 3 ready-to-go latest amd ryzen 3 7320u processor radeon graphics—ideal entire family, performance productivity core. visibly stunning: experience sharp details crisp colors 15.6" full hd ips display 16:9 aspect ratio narrow bezels.', 'internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.', 'wireless wi-fi 6 convenience: maintain strong, consistent wireless signal wi-fi 6 (aka 802.11ax) 2x2 mu-mimo technology. improved thermals: 78% increase fan surface area, enjoy improved thermal system additional 17% thermal capacity. allowing longer, efficient work sessions plugged in.', "ports accessories: 1 - usb type-c port usb ...
# Embeddings Shape:  (41, 384)
# Similar Chunks:  ['internal specifications: 8gb lpddr5 onboard memory; 128gb nvme solid-state drive storage store files media hd front-facing camera uses acer’s tnr (temporal noise reduction) technology high-quality imagery low-light conditions. acer purifiedvoice technology ai noise reduction filters extra sound clear communication online meetings.', 'purchase options add-ons brief content visible, double tap read full content. full content visible, double tap read brief content. product details top highlights item details display processor memory ports & slots brand acer model name laptop screen size 15.6 inches color silver hard disk size 128 gb cpu model ryzen 3 ram memory installed size 8 gb operating system windows 11 special feature backlit keyboard graphics card description integrated', 'brand acer model name laptop model year 2023 model number nx.kjbaa.001 built-in media laptop, power cord, ac adapter manufacturer acer upc 195133155014 customer reviews 4.2 5 stars best sellers rank #26 computers & accessories () #2 asin b0bs4bp8fb screen size 15.6 inches resolution 1080p native resolution 1920 x 1080 pixels display type lcd display resolution maximum 1920x1080 display technology lcd color screen yes screen finish matte']
# Response: ```json
# {
#   "front_camera": "yes"
# }
# ```
# Time: 2556.25 ms
# ==============================================================================
